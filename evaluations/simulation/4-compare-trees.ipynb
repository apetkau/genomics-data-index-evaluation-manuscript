# %%
library(ape)
library(phytools)
library(phangorn)
library(repr)

t_orig <- read.tree(file="input/salmonella.tre")
t_new <- read.tree(file="index/reads-tree.tre")

t_orig <- root(t_orig, "reference", resolve.root=TRUE)
t_new <- root(t_new, "reference", resolve.root=TRUE)

comparePhylo(t_orig, t_new, plot=TRUE)
# Out:
# => Comparing t_orig with t_new.
# Both trees have the same number of tips: 60.
# Both trees have the same tip labels.
# Both trees have the same number of nodes: 59.
# Both trees are rooted.
# Both trees are not ultrametric.
# 44 clades in t_orig not in t_new.
# 44 clades in t_new not in t_orig.
# Node labels of clades in common between both trees: see ..$NODES
# (node number in parentheses).
#
# $NODES
#            t_orig     t_new
# 1       Root (61) Root (61)
# 2   1.000000 (62)   1 (117)
# 3   0.000000 (63)   1 (106)
# 4   1.000000 (65)   1 (107)
# 5   0.920000 (67)   1 (109)
# 6   0.972000 (68)   1 (110)
# 7  -1.000000 (70)   1 (112)
# 8   0.990000 (75)      (62)
# 9   0.000000 (77)    1 (64)
# 10  1.000000 (78)    1 (65)
# 11  0.987000 (80)    1 (67)
# 12 1.000000 (107)    1 (94)
# 13 0.999000 (110)    1 (97)
# 14 0.917000 (118)   1 (101)
# 15          (119)   1 (119)
# Plot with title “t_new”

# %%
treedist(t_orig, t_new, check.labels = TRUE)
# Out:
#      symmetric.difference   branch.score.difference           path.difference
#                 88.000000                  0.287382                338.713743
# quadratic.path.difference
#                  7.962139

# %%
options(repr.plot.width=15, repr.plot.height=12)

plot(cophylo(t_orig, t_new, rotate=TRUE))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title
