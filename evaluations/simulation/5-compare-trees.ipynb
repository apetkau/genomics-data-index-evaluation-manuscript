# %% [markdown]
# # 1. Compare trees
#
# ## 1.1. Compare reads

# %%
library(ape)
library(phytools)
library(phangorn)
library(repr)

t_orig <- read.tree(file="input/salmonella.tre")
t_new_reads <- read.tree(file="index-reads/reads-tree.tre")

t_orig <- root(t_orig, "reference", resolve.root=TRUE)
t_new_reads <- root(t_new, "reference", resolve.root=TRUE)

comparePhylo(t_orig, t_new_reads, plot=FALSE)
# Out:
# => Comparing t_orig with t_new_reads.
# Both trees have the same number of tips: 60.
# Both trees have the same tip labels.
# Both trees have the same number of nodes: 59.
# Both trees are rooted.
# Both trees are not ultrametric.
# 41 clades in t_orig not in t_new_reads.
# 41 clades in t_new_reads not in t_orig.
# Node labels of clades in common between both trees: see ..$NODES
# (node number in parentheses).
#
# $NODES
#             t_orig t_new_reads
# 1        Root (61)   Root (61)
# 2    1.000000 (62)     1 (118)
# 3    0.000000 (63)     1 (107)
# 4    1.000000 (65)     1 (108)
# 5    0.920000 (67)     1 (110)
# 6    0.972000 (68)     1 (111)
# 7   -1.000000 (69)     1 (113)
# 8    0.990000 (75)      1 (63)
# 9    0.000000 (76)      1 (62)
# 10   0.000000 (77)      1 (65)
# 11   1.000000 (78)      1 (66)
# 12   0.987000 (80)      1 (68)
# 13  1.000000 (107)      1 (95)
# 14  0.999000 (110)      1 (98)
# 15 -1.000000 (116)     1 (100)
# 16  0.000000 (117)     1 (101)
# ...

# %%
treedist(t_orig, t_new_reads, check.labels = TRUE)
# Out:
#      symmetric.difference   branch.score.difference           path.difference
#                82.0000000                 0.2874021               374.5450574
# quadratic.path.difference
#                 7.9639717

# %%
options(repr.plot.width=15, repr.plot.height=16)

plot(cophylo(t_orig, t_new_reads, rotate=TRUE))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title

# %% [markdown]
# ## 1.2. Compare assemblies

# %%
t_new_assemblies <- read.tree(file="index-assemblies/assemblies-tree.tre")
t_new_assemblies <- root(t_new, "reference", resolve.root=TRUE)

comparePhylo(t_orig, t_new, plot=FALSE)
# Out:
# => Comparing t_orig with t_new.
# Both trees have the same number of tips: 60.
# Both trees have the same tip labels.
# Both trees have the same number of nodes: 59.
# Both trees are rooted.
# Both trees are not ultrametric.
# 41 clades in t_orig not in t_new.
# 41 clades in t_new not in t_orig.
# Node labels of clades in common between both trees: see ..$NODES
# (node number in parentheses).
#
# $NODES
#             t_orig     t_new
# 1        Root (61) Root (61)
# 2    1.000000 (62)   1 (118)
# 3    0.000000 (63)   1 (107)
# 4    1.000000 (65)   1 (108)
# 5    0.920000 (67)   1 (110)
# 6    0.972000 (68)   1 (111)
# 7   -1.000000 (69)   1 (113)
# 8    0.990000 (75)    1 (63)
# 9    0.000000 (76)      (62)
# 10   0.000000 (77)    1 (65)
# 11   1.000000 (78)    1 (66)
# 12   0.987000 (80)    1 (68)
# 13  1.000000 (107)    1 (95)
# 14  0.999000 (110)    1 (98)
# 15 -1.000000 (116)   1 (100)
# 16  0.000000 (117)   1 (101)
# 17  0.917000 (118)   1 (102)
# 18           (119)   1 (119)

# %%
treedist(t_orig, t_new_assemblies, check.labels = TRUE)
# Out:
#      symmetric.difference   branch.score.difference           path.difference
#                82.0000000                 0.2874021               374.5450574
# quadratic.path.difference
#                 7.9639717

# %%
options(repr.plot.width=15, repr.plot.height=16)

plot(cophylo(t_orig, t_new_assemblies, rotate=TRUE))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title

# %% [markdown]
# ## 1.3. Compare reads to assemblies tree

# %%
treedist(t_new_assemblies, t_new_reads, check.labels = TRUE)
# Out:
#      symmetric.difference   branch.score.difference           path.difference
#                         0                         0                         0
# quadratic.path.difference
#                         0

# %%
options(repr.plot.width=15, repr.plot.height=16)

plot(cophylo(t_new_assemblies, t_new_reads, rotate=TRUE))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title
