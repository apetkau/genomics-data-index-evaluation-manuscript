# %% [markdown]
# # 1. Prepare input metadata file

# %%
import pandas as pd

metadata_df = pd.read_csv('../input/metadata-subsample-pangolin.tsv', sep='\t').set_index('strain')
metadata_df
# Out:
#                                  virus   gisaid_epi_isl genbank_accession  \
# strain
# OU420663                          ncov                ?          OU420663
# USA/NY-CUIMC-NP-3606/2020         ncov                ?          MZ702266
# Switzerland/BL-UHB-42491849/2020  ncov   EPI_ISL_930932          OU281100
# Scotland/QEUH-1618558/2021        ncov  EPI_ISL_2487678          OU314699
# Scotland/QEUH-16829C6/2021        ncov  EPI_ISL_2554507          OU329920
# ...                                ...              ...               ...
# USA/OH-CDC-QDX23654955/2021       ncov  EPI_ISL_1669162          MW989219
# USA/KS-CDC-LC0014845/2021         ncov  EPI_ISL_1255089          MW704675
# USA/WA-S5065/2020                 ncov  EPI_ISL_1114222          MW689132
# England/MILK-10AE881/2021         ncov   EPI_ISL_993691          OD978562
# England/ALDP-B5B038/2020          ncov   EPI_ISL_655604          OB997017
#
# ...

# %%
samples_df = pd.read_csv('../cases/case-500/input-files-case.tsv', sep='\t')
samples_df
# Out:
#                        Sample  \
# 0    Wuhan/IPBCAMS-WH-04/2019
# 1     CHN/Wuhan_IME-WH05/2019
# 2                    FR993751
# 3     Switzerland/100080/2020
# 4     Switzerland/100076/2020
# ..                        ...
# 495           USA/WA-S92/2020
# 496          USA/WA-S100/2020
# 497                  LC581372
# 498          FRA/KRA-ROB/2020
# 499     USA/VA-DCLS-0005/2020
#
#                                             Assemblies  Reads1  Reads2
# 0    /home/CSCScience.ca/apetkau/workspace/genomics...     NaN     NaN
# 1    /home/CSCScience.ca/apetkau/workspace/genomics...     NaN     NaN
# 2    /home/CSCScience.ca/apetkau/workspace/genomics...     NaN     NaN
# 3    /home/CSCScience.ca/apetkau/workspace/genomics...     NaN     NaN
# 4    /home/CSCScience.ca/apetkau/workspace/genomics...     NaN     NaN
# ..                                                 ...     ...     ...
# 495  /home/CSCScience.ca/apetkau/workspace/genomics...     NaN     NaN
# ...

# %% [markdown]
# # 2. Subset metadata

# %%
metadata_500_df = metadata_df.loc[samples_df['Sample'].tolist()]
metadata_500_df
# Out:
#                          virus  gisaid_epi_isl genbank_accession  \
# strain
# Wuhan/IPBCAMS-WH-04/2019  ncov  EPI_ISL_403929          MT019532
# CHN/Wuhan_IME-WH05/2019   ncov  EPI_ISL_529217          MT291830
# FR993751                  ncov               ?          FR993751
# Switzerland/100080/2020   ncov               ?          LR824224
# Switzerland/100076/2020   ncov               ?          LR824229
# ...                        ...             ...               ...
# USA/WA-S92/2020           ncov  EPI_ISL_417145          MT627261
# USA/WA-S100/2020          ncov  EPI_ISL_417153          MT627315
# LC581372                  ncov  EPI_ISL_582143          LC581372
# FRA/KRA-ROB/2020          ncov  EPI_ISL_424993          MT320538
# USA/VA-DCLS-0005/2020     ncov  EPI_ISL_419256          MT322398
#
#                          sra_accession        date         region  \
# strain
# Wuhan/IPBCAMS-WH-04/2019           NaN  2019-12-30           Asia
# ...

# %%
metadata_500_df.to_csv('metadata-500.tsv', sep='\t')
