# %% [markdown]
# # 1. Parameters

# %%
sequences_split_dir = 'input/split'
sequences_subset_all = 'input/all.fasta.gz'
pangolin_out_dir = 'input/pangolin'
subset_metadata_path = 'input/metadata-subsample.tsv'
output_metadata_pangolin_path = 'input/metadata-subsample-pangolin.tsv'

# %%
from pathlib import Path

sequences_split_dir = Path(sequences_split_dir)
sequences_subset_all = Path(sequences_subset_all)
pangolin_out_dir = Path(pangolin_out_dir)
subset_metadata_path = Path(subset_metadata_path)
output_metadata_pangolin_path = Path(output_metadata_pangolin_path)

# %% [markdown]
# # 2. Run pangolin

# %%
# !conda run --name pangolin pangolin --all-versions
# Out:
# pangolin: 3.1.11
# pangolearn: 2021-08-24
# constellations: v0.0.15
# scorpio: 0.3.12
# pango-designation: 1.2.76

# %%
# !conda run --name pangolin pangolin -t 52 -o {pangolin_out_dir} {sequences_subset_all}
# Out:
# loading model 09/07/2021, 19:07:13
# processing block of 1000 sequences 09/07/2021, 19:07:26
# processing block of 1000 sequences 09/07/2021, 19:07:51
# processing block of 1000 sequences 09/07/2021, 19:08:17
# processing block of 1000 sequences 09/07/2021, 19:08:42
# processing block of 1000 sequences 09/07/2021, 19:09:08
# processing block of 1000 sequences 09/07/2021, 19:09:34
# processing block of 1000 sequences 09/07/2021, 19:09:59
# processing block of 148 sequences 09/07/2021, 19:10:15
# complete 09/07/2021, 19:10:18
# Output file written to: /home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/pangolin/lineage_report.csv
# All dependencies satisfied.
# The query file is:/home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/all.fasta.gz
# ** Sequence QC **
# Sequence name                 	                   Reason	Value
#
# OU419196                      	       N content too high	0.34
#
# OU419643                      	       N content too high	0.32
#
# LR991232                      	       N content too high	0.65
#
# LR991192                      	       N content too high	0.85
#
# USA/UT-UPHL-201007956/2020    	       N content too high	0.33
#
# USA/UT-UPHL-201027561/2020    	       N content too high	0.32
#
# USA/MA-Broad_UMMS-00174/2020  	       N content too high	0.46
#
# Iceland/6451/2020             	       N content too high	0.62
#
# LR963346                      	       N content too high	0.58
#
# OU390314                      	       N content too high	0.38
#
# Iceland/5021/2020             	       N content too high	0.4
#
# Switzerland/BE-ETHZ-340169/2020	       N content too high	0.32
#
# Switzerland/BE-ETHZ-350180/2020	       N content too high	0.32
#
# USA/CA-UCSC-603/2020          	       N content too high	0.38
#
# OU031475                      	       N content too high	0.42
#
# USA/VA-CDC-LC0000688/2020     	       N content too high	0.36
#
# USA/IN-CDC-LC0001462/2020     	       N content too high	0.39
#
# USA/MD-CDC-LC0002143/2020     	       N content too high	0.35
#
# USA/PA-CDC-LC0002911/2020     	       N content too high	0.33
#
# USA/CA-CDC-LC0002796/2021     	       N content too high	0.43
#
# USA/PA-CDC-LC0004486/2021     	       N content too high	0.39
#
# USA/AR-CDC-LC0003058/2021     	       N content too high	0.32
#
# USA/WI-CDC-LC0003284/2021     	       N content too high	0.46
#
# USA/FL-CDC-LC0005920/2021     	       N content too high	0.36
#
# USA/WV090175/2021             	       N content too high	0.36
#
# USA/MA-MASPHL-01585/2021      	       N content too high	0.38
#
# USA/VA-CDC-LC0007485/2021     	       N content too high	0.33
#
# USA/MI-CDC-LC0008539/2021     	       N content too high	0.46
#
# OU421574                      	       N content too high	0.37
#
# USA/TN-CDC-LC0010167/2021     	       N content too high	0.33
#
# USA/VA-CDC-LC0010506/2021     	       N content too high	0.36
#
# USA/PA-CDC-LC0010952/2021     	       N content too high	0.48
#
# USA/UND-00065852/2021         	       N content too high	0.49
#
# USA/MA-CDC-LC0012142/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0011920/2021     	       N content too high	0.43
#
# OU393363                      	       N content too high	0.42
#
# USA/CT-CDC-LC0012626/2021     	       N content too high	0.49
#
# USA/NM-CDC-LC0013284/2021     	       N content too high	0.32
#
# USA/FL-CDC-LC0013765/2021     	       N content too high	0.44
#
# OU029410                      	       N content too high	0.37
#
# OU030431                      	       N content too high	0.34
#
# USA/NC-CDC-LC0014313/2021     	       N content too high	0.32
#
# USA/NJ-CDC-LC0014810/2021     	       N content too high	0.37
#
# USA/NJ-CDC-LC0016358/2021     	       N content too high	0.43
#
# USA/VA-CDC-LC0016116/2021     	       N content too high	0.34
#
# USA/MD-CDC-LC0020341/2021     	       N content too high	0.36
#
# USA/NC-CDC-LC0020386/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0023369/2021     	       N content too high	0.47
#
# USA/ID-CDC-LC0026419/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0026086/2021     	       N content too high	0.4
#
# USA/CA-CDC-LC0027810/2021     	       N content too high	0.45
#
# USA/NC-CDC-LC0025580/2021     	       N content too high	0.37
#
# USA/NC-CDC-LC0026247/2021     	       N content too high	0.33
#
# OU391494                      	       N content too high	0.43
#
# USA/FL-CDC-LC0029864/2021     	       N content too high	0.33
#
# OB998378                      	       N content too high	0.33
#
# Estonia/Cov10570/2021         	       N content too high	0.44
#
# Estonia/Cov11005/2021         	       N content too high	0.32
#
# Switzerland/BE-ETHZ-610650/2021	       N content too high	0.31
#
# OU420951                      	       N content too high	0.42
#
# OU418445                      	       N content too high	0.44
#
# OU347940                      	       N content too high	0.42
#
# OU386014                      	       N content too high	0.36
#
# OU447304                      	       N content too high	0.49
#
# OU488487                      	       N content too high	0.36
#
# HG999994                      	       N content too high	0.5
#
#
# Number of sequences detected: 10000
# Total passing QC: 9934
#
# Data files found:
# Trained model:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTree_v1.joblib
# Header file:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTreeHeaders_v1.joblib
# Designated hash:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/lineages.hash.csv
#
# Job stats:
# job                     count    min threads    max threads
# --------------------  -------  -------------  -------------
# add_failed_seqs             1              1              1
# align_to_reference          1              1              1
# all                         1              1              1
# generate_report             1              1              1
# get_constellations          1              1              1
# hash_sequence_assign        1              1              1
# pangolearn                  1              1              1
# scorpio                     1             52             52
# total                       8              1             52
#
# /home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # 3. Load up and join pangolin to metadata
#
# ## 3.1. Load pangolin results

# %%
import pandas as pd

pangolin_report = pangolin_out_dir / 'lineage_report.csv'

p_df = pd.read_csv(pangolin_report)
p_df
# Out:
#                         taxon     lineage  conflict  ambiguity_score  \
# 0     Switzerland/100118/2020         B.1       NaN              NaN
# 1                    LR884325         B.1       NaN              NaN
# 2                    LR884332         B.1       NaN              NaN
# 3                    LR898961  B.1.177.23       NaN              NaN
# 4           AUS/VIC16054/2020         D.2       NaN              NaN
# ...                       ...         ...       ...              ...
# 9995                 OU347940        None       NaN              NaN
# 9996                 OU386014        None       NaN              NaN
# 9997                 OU447304        None       NaN              NaN
# 9998                 OU488487        None       NaN              NaN
# 9999                 HG999994        None       NaN              NaN
#
#      scorpio_call  scorpio_support  scorpio_conflict        version  \
# 0             NaN              NaN               NaN  PANGO-v1.2.66
# 1             NaN              NaN               NaN  PANGO-v1.2.66
# 2             NaN              NaN               NaN  PANGO-v1.2.66
# 3             NaN              NaN               NaN  PANGO-v1.2.66
# 4             NaN              NaN               NaN  PANGO-v1.2.66
# ...           ...              ...               ...            ...
# 9995          NaN              NaN               NaN  PANGO-v1.2.66
# 9996          NaN              NaN               NaN  PANGO-v1.2.66
# 9997          NaN              NaN               NaN  PANGO-v1.2.66
# 9998          NaN              NaN               NaN  PANGO-v1.2.66
# 9999          NaN              NaN               NaN  PANGO-v1.2.66
#
#      pangolin_version pangoLEARN_version pango_version     status  \
# 0              3.1.11         2021-08-24       v1.2.66  passed_qc
# 1              3.1.11         2021-08-24       v1.2.66  passed_qc
# 2              3.1.11         2021-08-24       v1.2.66  passed_qc
# 3              3.1.11         2021-08-24       v1.2.66  passed_qc
# 4              3.1.11         2021-08-24       v1.2.66  passed_qc
# ...               ...                ...           ...        ...
# 9995           3.1.11         2021-08-24       v1.2.66       fail
# 9996           3.1.11         2021-08-24       v1.2.66       fail
# 9997           3.1.11         2021-08-24       v1.2.66       fail
# 9998           3.1.11         2021-08-24       v1.2.66       fail
# 9999           3.1.11         2021-08-24       v1.2.66       fail
#
#                                  note
# 0     Assigned from designation hash.
# 1     Assigned from designation hash.
# 2     Assigned from designation hash.
# 3     Assigned from designation hash.
# 4     Assigned from designation hash.
# ...                               ...
# 9995                   N_content:0.42
# 9996                   N_content:0.36
# 9997                   N_content:0.49
# 9998                   N_content:0.36
# 9999                    N_content:0.5
#
# [10000 rows x 13 columns]

# %% [markdown]
# ## 3.2. Load other metadata

# %%
import pandas as pd

metadata_df = pd.read_csv(subset_metadata_path, sep='\t')
metadata_df
# Out:
#                              strain virus   gisaid_epi_isl genbank_accession  \
# 0          England/MILK-BB1C0F/2020  ncov   EPI_ISL_720301          OD907972
# 1              USA/MN-MDH-6083/2021  ncov  EPI_ISL_1820970          MZ066570
# 2     USA/PA-CDC-STM-000058747/2021  ncov  EPI_ISL_1923233          MZ132284
# 3         USA/NJ-CDC-LC0045907/2021  ncov  EPI_ISL_1799871          MZ070532
# 4                          OU098600  ncov                ?          OU098600
# ...                             ...   ...              ...               ...
# 9995      England/MILK-19AF720/2021  ncov  EPI_ISL_3107867          OU464432
# 9996      England/PLYM-19DF208/2021  ncov  EPI_ISL_3124091          OU467577
# 9997    USA/CO-CDC-MMB08815626/2021  ncov  EPI_ISL_2440926          MZ354711
# 9998      England/ALDP-12C3E19/2021  ncov  EPI_ISL_1071782          OU011022
# 9999      England/QEUH-17FE9C4/2021  ncov  EPI_ISL_2830208          OU392428
#
#      sra_accession        date         region         country  \
# 0       ERR5021413  2020-11-18         Europe  United Kingdom
# 1              NaN  2021-04-15  North America             USA
# 2              NaN  2021-04-18  North America             USA
# 3              NaN  2021-04-09  North America             USA
# 4              NaN         NaN         Europe         Germany
# ...            ...         ...            ...             ...
# 9995    ERR6380849  2021-07-17         Europe  United Kingdom
# 9996    ERR6387813  2021-07-22         Europe  United Kingdom
# 9997           NaN  2021-05-14  North America             USA
# 9998    ERR5380776  2021-02-14         Europe  United Kingdom
# 9999    ERR6200982  2021-06-29         Europe  United Kingdom
#
#                     division location  ... divergence nonACGTN rare_mutations  \
# 0                    England      NaN  ...       19.0      0.0            5.0
# 1                  Minnesota      NaN  ...       33.0      0.0            5.0
# 2               Pennsylvania      NaN  ...       43.0      0.0           15.0
# 3                 New Jersey      NaN  ...       20.0      0.0            4.0
# 4     North Rhine Westphalia      NaN  ...       35.0      0.0            8.0
# ...                      ...      ...  ...        ...      ...            ...
# 9995                 England      NaN  ...       33.0      0.0            6.0
# 9996                 England      NaN  ...       38.0      0.0            7.0
# 9997                Colorado      NaN  ...       44.0      0.0           12.0
# 9998                 England      NaN  ...       32.0      0.0            8.0
# 9999                 England      NaN  ...       35.0      0.0            6.0
#
#      snp_clusters  QC_missing_data QC_mixed_sites QC_rare_mutations  \
# 0             0.0             good           good              good
# 1             0.0         mediocre           good              good
# 2             0.0             good           good              good
# 3             0.0             good           good              good
# 4             0.0             good           good              good
# ...           ...              ...            ...               ...
# 9995          0.0         mediocre           good              good
# 9996          0.0             good           good              good
# 9997          0.0             good           good              good
# 9998          0.0             good           good              good
# 9999          0.0             good           good              good
#
#      QC_snp_clusters clock_deviation missing_data_percent
# 0               good             0.0             0.404642
# 1               good            -3.0             4.340702
# 2               good             6.0             0.000000
# 3               good            -4.0             0.000000
# 4               good               ?             0.013377
# ...              ...             ...                  ...
# 9995            good            -4.0             3.905963
# 9996            good             0.0             0.404642
# 9997            good             5.0             0.000000
# 9998            good             0.0             0.404642
# 9999            good            -1.0             1.320938
#
# [10000 rows x 40 columns]

# %%
metadata_df.columns
# Out:
# Index(['strain', 'virus', 'gisaid_epi_isl', 'genbank_accession',
#        'sra_accession', 'date', 'region', 'country', 'division', 'location',
#        'region_exposure', 'country_exposure', 'division_exposure', 'segment',
#        'length', 'host', 'age', 'sex', 'Nextstrain_clade', 'pango_lineage',
#        'GISAID_clade', 'originating_lab', 'submitting_lab', 'authors', 'url',
#        'title', 'paper_url', 'date_submitted', 'sampling_strategy',
#        'missing_data', 'divergence', 'nonACGTN', 'rare_mutations',
#        'snp_clusters', 'QC_missing_data', 'QC_mixed_sites',
#        'QC_rare_mutations', 'QC_snp_clusters', 'clock_deviation',
#        'missing_data_percent'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Join to pangolin results

# %%
metadata_pangolin_df = metadata_df.merge(p_df, left_on='strain', right_on='taxon')
metadata_pangolin_df
# Out:
#                              strain virus   gisaid_epi_isl genbank_accession  \
# 0          England/MILK-BB1C0F/2020  ncov   EPI_ISL_720301          OD907972
# 1              USA/MN-MDH-6083/2021  ncov  EPI_ISL_1820970          MZ066570
# 2     USA/PA-CDC-STM-000058747/2021  ncov  EPI_ISL_1923233          MZ132284
# 3         USA/NJ-CDC-LC0045907/2021  ncov  EPI_ISL_1799871          MZ070532
# 4                          OU098600  ncov                ?          OU098600
# ...                             ...   ...              ...               ...
# 9995      England/MILK-19AF720/2021  ncov  EPI_ISL_3107867          OU464432
# 9996      England/PLYM-19DF208/2021  ncov  EPI_ISL_3124091          OU467577
# 9997    USA/CO-CDC-MMB08815626/2021  ncov  EPI_ISL_2440926          MZ354711
# 9998      England/ALDP-12C3E19/2021  ncov  EPI_ISL_1071782          OU011022
# 9999      England/QEUH-17FE9C4/2021  ncov  EPI_ISL_2830208          OU392428
#
#      sra_accession        date         region         country  \
# 0       ERR5021413  2020-11-18         Europe  United Kingdom
# 1              NaN  2021-04-15  North America             USA
# 2              NaN  2021-04-18  North America             USA
# 3              NaN  2021-04-09  North America             USA
# 4              NaN         NaN         Europe         Germany
# ...            ...         ...            ...             ...
# 9995    ERR6380849  2021-07-17         Europe  United Kingdom
# 9996    ERR6387813  2021-07-22         Europe  United Kingdom
# 9997           NaN  2021-05-14  North America             USA
# 9998    ERR5380776  2021-02-14         Europe  United Kingdom
# 9999    ERR6200982  2021-06-29         Europe  United Kingdom
#
#                     division location  ... ambiguity_score  \
# 0                    England      NaN  ...             NaN
# 1                  Minnesota      NaN  ...        0.946374
# 2               Pennsylvania      NaN  ...        1.000000
# 3                 New Jersey      NaN  ...        1.000000
# 4     North Rhine Westphalia      NaN  ...        1.000000
# ...                      ...      ...  ...             ...
# 9995                 England      NaN  ...        0.961325
# 9996                 England      NaN  ...        1.000000
# 9997                Colorado      NaN  ...        1.000000
# 9998                 England      NaN  ...        1.000000
# 9999                 England      NaN  ...        0.989724
#
#                 scorpio_call scorpio_support scorpio_conflict         version  \
# 0                        NaN             NaN              NaN   PANGO-v1.2.66
# 1       Alpha (B.1.1.7-like)          0.9130           0.0435  PLEARN-v1.2.66
# 2       Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# 3        Iota (B.1.526-like)          0.8261           0.1739  PLEARN-v1.2.66
# 4       Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# ...                      ...             ...              ...             ...
# 9995  Delta (B.1.617.2-like)          0.7692           0.0000  PLEARN-v1.2.66
# 9996  Delta (B.1.617.2-like)          1.0000           0.0000  PLEARN-v1.2.66
# 9997        Gamma (P.1-like)          0.8750           0.0000  PLEARN-v1.2.66
# 9998    Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# 9999  Delta (B.1.617.2-like)          0.9231           0.0000  PLEARN-v1.2.66
#
#      pangolin_version pangoLEARN_version pango_version     status  \
# 0              3.1.11         2021-08-24       v1.2.66  passed_qc
# 1              3.1.11         2021-08-24       v1.2.66  passed_qc
# 2              3.1.11         2021-08-24       v1.2.66  passed_qc
# 3              3.1.11         2021-08-24       v1.2.66  passed_qc
# 4              3.1.11         2021-08-24       v1.2.66  passed_qc
# ...               ...                ...           ...        ...
# 9995           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9996           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9997           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9998           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9999           3.1.11         2021-08-24       v1.2.66  passed_qc
#
#                                                    note
# 0                       Assigned from designation hash.
# 1     scorpio call: Alt alleles 21; Ref alleles 1; A...
# 2     scorpio call: Alt alleles 22; Ref alleles 1; A...
# 3     scorpio call: Alt alleles 19; Ref alleles 4; A...
# 4     scorpio call: Alt alleles 22; Ref alleles 1; A...
# ...                                                 ...
# 9995  scorpio call: Alt alleles 10; Ref alleles 0; A...
# 9996  scorpio call: Alt alleles 13; Ref alleles 0; A...
# 9997  scorpio call: Alt alleles 14; Ref alleles 0; A...
# 9998  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9999  scorpio call: Alt alleles 12; Ref alleles 0; A...
#
# [10000 rows x 53 columns]

# %% [markdown]
# # 4. Save joined metadata to file

# %%
metadata_pangolin_df.to_csv(output_metadata_pangolin_path, sep='\t', index=False)

print(f'Saved metadata and pangolin to {output_metadata_pangolin_path}')
# Out:
# Saved metadata and pangolin to input/metadata-subsample-pangolin.tsv
