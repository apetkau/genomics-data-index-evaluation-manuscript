# %% [markdown]
# # 1. Parameters

# %%
sequences_split_dir = 'input/split'
sequences_subset_all = 'input/all.fasta.gz'
pangolin_out_dir = 'input/pangolin'
subset_metadata_path = 'input/metadata-subsample.tsv'
output_metadata_pangolin_path = 'input/metadata-subsample-pangolin.tsv'

# %%
from pathlib import Path

sequences_split_dir = Path(sequences_split_dir)
sequences_subset_all = Path(sequences_subset_all)
pangolin_out_dir = Path(pangolin_out_dir)
subset_metadata_path = Path(subset_metadata_path)
output_metadata_pangolin_path = Path(output_metadata_pangolin_path)

# %% [markdown]
# # 2. Run pangolin

# %%
# !conda run --name pangolin pangolin --all-versions
# Out:
# pangolin: 3.1.11
# pangolearn: 2021-08-24
# constellations: v0.0.15
# scorpio: 0.3.12
# pango-designation: 1.2.76

# %%
# !conda run --name pangolin pangolin -t 52 -o {pangolin_out_dir} {sequences_subset_all}
# Out:
# All dependencies satisfied.
# The query file is:/home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/all.fasta.gz
# ** Sequence QC **
# Sequence name                 	                   Reason	Value
#
# OB998205                      	       N content too high	0.42
#
# OU395174                      	       N content too high	0.45
#
# OU419825                      	       N content too high	0.49
#
# OU421540                      	       N content too high	0.47
#
# OU487653                      	       N content too high	0.37
#
# OU489002                      	       N content too high	0.45
#
# Japan/DP0700/2020             	            Seq too short	22839
#
# USA/20x1094/2020              	       N content too high	0.37
#
# USA/UT-01685/2020             	       N content too high	0.43
#
# KEN/C800/2020                 	       N content too high	0.46
#
# HG996918                      	       N content too high	0.33
#
# LR991264                      	       N content too high	0.37
#
# LR991128                      	       N content too high	0.46
#
# LR991112                      	       N content too high	0.48
#
# England/NORW-EB51B/2020       	       N content too high	0.37
#
# England/NORW-EB1DB/2020       	       N content too high	0.31
#
# LR991143                      	       N content too high	0.36
#
# LR991591                      	       N content too high	0.35
#
# LR899041                      	       N content too high	0.47
#
# LR991516                      	       N content too high	0.31
#
# USA/UT-UPHL-201022783/2020    	       N content too high	0.36
#
# KEN/C38852/2020               	       N content too high	0.34
#
# Switzerland/BL-ETHZ-260029/2020	       N content too high	0.33
#
# Iceland/6668/2020             	       N content too high	0.36
#
# Iceland/6166/2020             	       N content too high	0.37
#
# Iceland/4250/2020             	       N content too high	0.44
#
# Iceland/4385/2020             	       N content too high	0.36
#
# Iceland/6036/2020             	       N content too high	0.35
#
# Iceland/4968/2020             	       N content too high	0.38
#
# HG994342                      	       N content too high	0.34
#
# USA/UT-UPHL-2012643349/2020   	       N content too high	0.45
#
# OU031266                      	       N content too high	0.32
#
# USA/UT-UPHL-2012009535/2020   	       N content too high	0.41
#
# USA/MA-Broad_UMMS-00063/2020  	       N content too high	0.43
#
# HG996904                      	       N content too high	0.37
#
# USA/UT-UPHL-2101396594/2020   	       N content too high	0.47
#
# HG996824                      	       N content too high	0.46
#
# USA/MA-MGH-03720/2020         	       N content too high	0.31
#
# USA/UT-UPHL-2101758216/2020   	       N content too high	0.46
#
# USA/AZ-CDC-LC0000212/2020     	       N content too high	0.49
#
# USA/MO-CDC-LC0000297/2020     	       N content too high	0.32
#
# USA/VA-CDC-LC0000573/2020     	       N content too high	0.49
#
# USA/GA-CDC-LC0000972/2020     	       N content too high	0.45
#
# USA/GA-CDC-LC0001408/2020     	       N content too high	0.32
#
# USA/GA-CDC-LC0002034/2020     	       N content too high	0.32
#
# Iceland/4088/2020             	       N content too high	0.32
#
# USA/GA-CDC-LC0001192/2020     	       N content too high	0.43
#
# USA/IL-CDC-LC0001841/2020     	       N content too high	0.36
#
# USA/GA-CDC-LC0002039/2020     	       N content too high	0.42
#
# USA/KY-CDC-LC0002178/2020     	       N content too high	0.45
#
# OU029950                      	       N content too high	0.43
#
# USA/NC-CDC-LC0002217/2020     	       N content too high	0.43
#
# USA/NC-CDC-LC0002241/2020     	       N content too high	0.45
#
# USA/MT-CDC-LC0002525/2020     	       N content too high	0.4
#
# USA/PA-CDC-LC0003012/2020     	       N content too high	0.33
#
# HG997192                      	       N content too high	0.46
#
# USA/MA-MASPHL-01404/2020      	       N content too high	0.34
#
# USA/AL-CDC-LC0002869/2020     	       N content too high	0.46
#
# USA/NY-CDC-LC0002950/2020     	       N content too high	0.36
#
# USA/NM-CDC-LC0003931/2020     	       N content too high	0.39
#
# USA/FL-CDC-LC0002443/2021     	       N content too high	0.43
#
# OU418158                      	       N content too high	0.48
#
# HG997194                      	       N content too high	0.43
#
# USA/TX-CDC-LC0002270/2021     	       N content too high	0.46
#
# USA/IN-CDC-LC0004001/2021     	       N content too high	0.46
#
# USA/IL-CDC-LC0004111/2021     	       N content too high	0.46
#
# USA/WI-CDC-LC0004123/2021     	       N content too high	0.33
#
# USA/MO-CDC-LC0004202/2021     	       N content too high	0.42
#
# USA/AR-CDC-LC0004441/2021     	       N content too high	0.39
#
# USA/MI-CDC-LC0004547/2021     	       N content too high	0.32
#
# OU421382                      	       N content too high	0.41
#
# USA/WI-CDC-LC0004103/2021     	       N content too high	0.33
#
# USA/WI-CDC-LC0004133/2021     	       N content too high	0.36
#
# Switzerland/BL-ETHZ-440117/2021	       N content too high	0.32
#
# USA/VA-CDC-LC0002561/2021     	       N content too high	0.36
#
# USA/UT-CDC-LC0004270/2021     	       N content too high	0.43
#
# USA/CT-CDC-LC0004465/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0004474/2021     	       N content too high	0.36
#
# USA/PA-CDC-LC0004486/2021     	       N content too high	0.39
#
# USA/MT-CDC-LC0004926/2021     	       N content too high	0.36
#
# Switzerland/AG-ETHZ-440883/2020	       N content too high	0.31
#
# USA/NE-CDC-LC0004851/2021     	       N content too high	0.39
#
# USA/DC-CDC-LC0004863/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0004933/2021     	       N content too high	0.37
#
# USA/VA-CDC-LC0004936/2021     	       N content too high	0.33
#
# USA/DC-CDC-LC0005031/2021     	       N content too high	0.46
#
# USA/FL-CDC-LC0005093/2021     	       N content too high	0.46
#
# OU031523                      	       N content too high	0.49
#
# USA/NC-CDC-LC0005155/2021     	       N content too high	0.43
#
# USA/NC-CDC-LC0005156/2021     	       N content too high	0.46
#
# OU447041                      	       N content too high	0.42
#
# USA/NM-CDC-LC0005381/2021     	       N content too high	0.33
#
# USA/KS-CDC-LC0005534/2021     	       N content too high	0.42
#
# OU448270                      	       N content too high	0.44
#
# USA/UT-UPHL-2101538335/2021   	       N content too high	0.48
#
# USA/NV-CDC-LC0003123/2021     	       N content too high	0.32
#
# USA/NM-CDC-LC0005307/2021     	       N content too high	0.43
#
# USA/KS-CDC-LC0005548/2021     	       N content too high	0.4
#
# OU396121                      	       N content too high	0.35
#
# USA/AZ-CDC-LC0003111/2021     	       N content too high	0.43
#
# USA/AZ-CDC-LC0003116/2021     	       N content too high	0.4
#
# USA/MO-CDC-LC0003207/2021     	       N content too high	0.39
#
# USA/NE-CDC-LC0003212/2021     	       N content too high	0.46
#
# USA/UT-UPHL-2102251327/2021   	       N content too high	0.36
#
# USA/MA-MASPHL-01607/2021      	       N content too high	0.4
#
# USA/UT-UPHL-2101721933/2021   	       N content too high	0.44
#
# USA/LA-CDC-LC0003581/2021     	       N content too high	0.43
#
# USA/LA-CDC-LC0003594/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0003651/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0003652/2021     	       N content too high	0.33
#
# USA/DC-CDC-LC0003725/2021     	       N content too high	0.4
#
# USA/NC-CDC-LC0003898/2021     	       N content too high	0.33
#
# USA/DC-CDC-LC0003912/2021     	       N content too high	0.39
#
# OB998487                      	       N content too high	0.44
#
# OU029177                      	       N content too high	0.39
#
# OU394855                      	       N content too high	0.34
#
# USA/IN-CDC-LC0005594/2021     	       N content too high	0.36
#
# USA/IL-CDC-LC0005595/2021     	       N content too high	0.37
#
# USA/WA-CDC-LC0005614/2021     	       N content too high	0.4
#
# USA/NY-CDC-LC0005824/2021     	       N content too high	0.33
#
# USA/CA-CDC-LC0007619/2021     	       N content too high	0.46
#
# Switzerland/BS-ETHZ-460393/2021	       N content too high	0.31
#
# OU030630                      	       N content too high	0.4
#
# USA/AZ-CDC-LC0005739/2021     	       N content too high	0.46
#
# USA/MA-CDC-LC0006095/2021     	       N content too high	0.4
#
# OU421247                      	       N content too high	0.4
#
# USA/NC-CDC-LC0005945/2021     	       N content too high	0.47
#
# USA/SC-CDC-LC0005970/2021     	       N content too high	0.46
#
# USA/MD-CDC-LC0006002/2021     	       N content too high	0.45
#
# USA/MD-CDC-LC0007899/2021     	       N content too high	0.32
#
# USA/UT-UPHL-2104479709/2021   	       N content too high	0.37
#
# Switzerland/JU-ETHZ-460091/2021	       N content too high	0.32
#
# OU029180                      	       N content too high	0.5
#
# OU393299                      	       N content too high	0.47
#
# USA/NC-CDC-LC0006557/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0006563/2021     	       N content too high	0.43
#
# USA/IL-CDC-LC0006607/2021     	       N content too high	0.32
#
# USA/GA-CDC-LC0006634/2021     	       N content too high	0.46
#
# USA/GA-CDC-LC0007135/2021     	       N content too high	0.36
#
# USA/NJ-CDC-LC0007218/2021     	       N content too high	0.33
#
# USA/NC-CDC-LC0007348/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0007403/2021     	       N content too high	0.46
#
# USA/MN-CDC-LC0007431/2021     	       N content too high	0.33
#
# USA/NC-CDC-LC0008070/2021     	       N content too high	0.36
#
# USA/CT-CDC-LC0008123/2021     	       N content too high	0.46
#
# USA/MO-CDC-LC0008131/2021     	       N content too high	0.42
#
# USA/WY-CDC-LC0008464/2021     	       N content too high	0.36
#
# USA/NY-CDC-LC0008536/2021     	       N content too high	0.43
#
# OU388693                      	       N content too high	0.34
#
# USA/NC-CDC-LC0007364/2021     	       N content too high	0.36
#
# USA/NC-CDC-LC0007557/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0008255/2021     	       N content too high	0.43
#
# USA/NC-CDC-LC0008319/2021     	       N content too high	0.49
#
# USA/AZ-CDC-LC0008470/2021     	       N content too high	0.36
#
# USA/NV-CDC-LC0008516/2021     	       N content too high	0.43
#
# USA/KY-CDC-LC0008542/2021     	       N content too high	0.36
#
# USA/MO-CDC-LC0008630/2021     	       N content too high	0.43
#
# USA/AZ-CDC-LC0008682/2021     	       N content too high	0.31
#
# USA/PA-CDC-LC0008809/2021     	       N content too high	0.37
#
# USA/WI-CDC-LC0008747/2021     	       N content too high	0.43
#
# USA/PA-CDC-LC0009123/2021     	       N content too high	0.36
#
# OU030890                      	       N content too high	0.35
#
# OU423123                      	       N content too high	0.31
#
# USA/AZ-CDC-LC0009119/2021     	       N content too high	0.45
#
# Switzerland/TI-ETHZ-470173/2020	       N content too high	0.31
#
# USA/VA-CDC-LC0009630/2021     	       N content too high	0.46
#
# USA/NC-CDC-LC0010105/2021     	       N content too high	0.47
#
# USA/DE-CDC-LC0009340/2021     	       N content too high	0.36
#
# USA/VA-CDC-LC0009397/2021     	       N content too high	0.4
#
# OU394594                      	       N content too high	0.45
#
# USA/VA-CDC-LC0009408/2021     	       N content too high	0.46
#
# USA/VA-CDC-LC0009411/2021     	       N content too high	0.37
#
# USA/NC-CDC-LC0009463/2021     	       N content too high	0.36
#
# USA/GA-CDC-LC0009474/2021     	       N content too high	0.36
#
# USA/GA-CDC-LC0009497/2021     	       N content too high	0.43
#
# USA/VA-CDC-LC0009603/2021     	       N content too high	0.37
#
# USA/DC-CDC-LC0009612/2021     	       N content too high	0.46
#
# USA/NC-CDC-LC0009750/2021     	       N content too high	0.47
#
# USA/AL-CDC-LC0009845/2021     	       N content too high	0.48
#
# USA/GA-CDC-LC0009988/2021     	       N content too high	0.47
#
# USA/VA-CDC-LC0010225/2021     	       N content too high	0.4
#
# USA/MD-CDC-LC0010311/2021     	       N content too high	0.38
#
# USA/VA-CDC-LC0010617/2021     	       N content too high	0.4
#
# USA/KY-CDC-LC0011181/2021     	       N content too high	0.34
#
# USA/VA-CDC-LC0010337/2021     	       N content too high	0.33
#
# USA/NC-CDC-LC0010677/2021     	       N content too high	0.4
#
# USA/LA-CDC-LC0010689/2021     	       N content too high	0.33
#
# USA/GA-CDC-LC0010712/2021     	       N content too high	0.4
#
# USA/GA-CDC-LC0010739/2021     	       N content too high	0.36
#
# USA/NC-CDC-LC0011086/2021     	       N content too high	0.33
#
# USA/CA-Broad_FlowHealth-00083/2021	       N content too high	0.32
#
# OU396033                      	       N content too high	0.42
#
# USA/VA-CDC-LC0010974/2021     	       N content too high	0.49
#
# USA/MD-CDC-LC0011153/2021     	       N content too high	0.33
#
# USA/SD-CDC-LC0011638/2021     	       N content too high	0.32
#
# USA/NM-CDC-LC0011761/2021     	       N content too high	0.39
#
# USA/KS-CDC-LC0011523/2021     	       N content too high	0.47
#
# USA/AZ-CDC-LC0011730/2021     	       N content too high	0.33
#
# USA/AZ-CDC-LC0011743/2021     	       N content too high	0.36
#
# USA/AZ-CDC-LC0011782/2021     	       N content too high	0.43
#
# USA/AR-CDC-LC0011411/2021     	       N content too high	0.45
#
# USA/NV-CDC-LC0011855/2021     	       N content too high	0.32
#
# OU384886                      	       N content too high	0.39
#
# USA/KS-CDC-LC0011996/2021     	       N content too high	0.43
#
# USA/MI-CDC-LC0011927/2021     	       N content too high	0.32
#
# USA/OH-CDC-LC0011928/2021     	       N content too high	0.47
#
# USA/OR-CDC-LC0011962/2021     	       N content too high	0.45
#
# OU395824                      	       N content too high	0.34
#
# USA/CA-CDC-LC0012615/2021     	       N content too high	0.42
#
# USA/CA-CDC-LC0013598/2021     	       N content too high	0.4
#
# USA/CA-CDC-LC0013604/2021     	       N content too high	0.33
#
# USA/AZ-CDC-LC0012225/2021     	       N content too high	0.49
#
# USA/LA-CDC-LC0012851/2021     	       N content too high	0.43
#
# USA/ID-CDC-LC0013222/2021     	       N content too high	0.4
#
# USA/LA-CDC-LC0012850/2021     	       N content too high	0.36
#
# USA/CA-CDC-LC0013596/2021     	       N content too high	0.47
#
# USA/IN-CDC-LC0012323/2021     	       N content too high	0.32
#
# USA/LA-CDC-LC0012855/2021     	       N content too high	0.36
#
# USA/CA-CDC-LC0013251/2021     	       N content too high	0.39
#
# USA/NC-CDC-LC0012935/2021     	       N content too high	0.33
#
# USA/LA-CDC-LC0013549/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0012939/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0012347/2021     	       N content too high	0.34
#
# USA/FL-CDC-LC0013015/2021     	       N content too high	0.33
#
# OU419775                      	       N content too high	0.44
#
# USA/NC-CDC-LC0013159/2021     	       N content too high	0.31
#
# USA/PA-CDC-LC0013313/2021     	       N content too high	0.33
#
# USA/NE-CDC-LC0013691/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0013723/2021     	       N content too high	0.33
#
# USA/VA-CDC-LC0013142/2021     	       N content too high	0.45
#
# USA/MA-CDC-LC0013368/2021     	       N content too high	0.32
#
# OU423097                      	       N content too high	0.48
#
# USA/ID-CDC-LC0012092/2021     	       N content too high	0.35
#
# OU418317                      	       N content too high	0.34
#
# USA/NC-CDC-LC0014695/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0014703/2021     	       N content too high	0.39
#
# USA/NY-CDC-LC0014783/2021     	       N content too high	0.36
#
# USA/NJ-CDC-LC0014128/2021     	       N content too high	0.45
#
# USA/NJ-CDC-LC0014417/2021     	       N content too high	0.43
#
# USA/NV-CDC-LC0014510/2021     	       N content too high	0.36
#
# USA/AR-CDC-LC0014680/2021     	       N content too high	0.37
#
# USA/AR-CDC-LC0014681/2021     	       N content too high	0.37
#
# USA/LA-CDC-LC0015001/2021     	       N content too high	0.39
#
# USA/NY-CDC-LC0015042/2021     	       N content too high	0.4
#
# USA/CT-CDC-LC0016078/2021     	       N content too high	0.36
#
# USA/MD-CDC-LC0014470/2021     	       N content too high	0.36
#
# USA/NJ-CDC-LC0014556/2021     	       N content too high	0.4
#
# USA/AL-CDC-LC0014859/2021     	       N content too high	0.39
#
# USA/PA-CDC-LC0016460/2021     	       N content too high	0.33
#
# USA/NY-CDC-LC0016699/2021     	       N content too high	0.45
#
# USA/FL-CDC-LC0015006/2021     	       N content too high	0.36
#
# USA/VA-CDC-LC0015618/2021     	       N content too high	0.4
#
# USA/GA-CDC-LC0015668/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0015818/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0015938/2021     	       N content too high	0.47
#
# USA/FL-CDC-LC0015951/2021     	       N content too high	0.37
#
# USA/NC-CDC-LC0015253/2021     	       N content too high	0.33
#
# USA/VA-CDC-LC0015881/2021     	       N content too high	0.43
#
# USA/VA-CDC-LC0015931/2021     	       N content too high	0.39
#
# USA/CA-CDC-LC0016821/2021     	       N content too high	0.4
#
# USA/CA-CDC-LC0016846/2021     	       N content too high	0.45
#
# USA/NC-CDC-LC0016528/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0016883/2021     	       N content too high	0.33
#
# USA/NH-CDC-LC0017944/2021     	       N content too high	0.4
#
# USA/CT-CDC-LC0017951/2021     	       N content too high	0.37
#
# USA/MS-CDC-LC0016143/2021     	       N content too high	0.45
#
# USA/MA-CDC-LC0013853/2021     	       N content too high	0.37
#
# USA/MA-CDC-LC0013894/2021     	       N content too high	0.46
#
# USA/MA-CDC-LC0016428/2021     	       N content too high	0.36
#
# USA/MS-CDC-LC0016974/2021     	       N content too high	0.32
#
# USA/NH-CDC-LC0018066/2021     	       N content too high	0.4
#
# OU417630                      	       N content too high	0.33
#
# USA/KS-CDC-LC0018708/2021     	       N content too high	0.4
#
# OU392673                      	       N content too high	0.47
#
# HG997821                      	       N content too high	0.32
#
# USA/KY-CDC-LC0017305/2021     	       N content too high	0.4
#
# USA/GA-CDC-LC0018206/2021     	       N content too high	0.33
#
# USA/NC-CDC-LC0018441/2021     	       N content too high	0.42
#
# USA/NJ-CDC-LC0019102/2021     	       N content too high	0.46
#
# USA/UND-00056321/2021         	       N content too high	0.46
#
# OU391229                      	       N content too high	0.49
#
# USA/GA-CDC-LC0017482/2021     	       N content too high	0.43
#
# USA/CO-CDC-LC0019210/2021     	       N content too high	0.32
#
# USA/GA-CDC-LC0017722/2021     	       N content too high	0.33
#
# USA/MD-CDC-LC0018634/2021     	       N content too high	0.36
#
# USA/NJ-CDC-LC0019228/2021     	       N content too high	0.41
#
# USA/CA-CDC-LC0019426/2021     	       N content too high	0.4
#
# USA/NE-CDC-LC0019286/2021     	       N content too high	0.37
#
# USA/NM-CDC-LC0019347/2021     	       N content too high	0.36
#
# OU032490                      	       N content too high	0.39
#
# USA/WA-CDC-LC0019437/2021     	       N content too high	0.33
#
# OU385271                      	       N content too high	0.36
#
# USA/NC-CDC-LC0019647/2021     	       N content too high	0.36
#
# USA/CA-CDC-LC0024766/2021     	       N content too high	0.4
#
# OB998470                      	       N content too high	0.31
#
# USA/FL-CDC-LC0019954/2021     	       N content too high	0.4
#
# USA/CA-CDC-LC0024652/2021     	       N content too high	0.39
#
# USA/NC-CDC-LC0019886/2021     	       N content too high	0.33
#
# USA/PA-CDC-LC0020041/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0020062/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0020315/2021     	       N content too high	0.32
#
# USA/NY-CDC-LC0020594/2021     	       N content too high	0.46
#
# USA/NJ-CDC-LC0020102/2021     	       N content too high	0.33
#
# USA/OH-CDC-LC0020120/2021     	       N content too high	0.49
#
# USA/GA-CDC-LC0020176/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0020284/2021     	       N content too high	0.47
#
# USA/OH-CDC-LC0020521/2021     	       N content too high	0.33
#
# USA/OH-CDC-LC0020536/2021     	       N content too high	0.42
#
# USA/IN-CDC-LC0019845/2021     	       N content too high	0.4
#
# USA/AZ-CDC-LC0020393/2021     	       N content too high	0.33
#
# USA/NY-CDC-LC0020648/2021     	       N content too high	0.37
#
# USA/NC-CDC-LC0020785/2021     	       N content too high	0.43
#
# USA/NC-CDC-LC0020387/2021     	       N content too high	0.33
#
# USA/IL-CDC-LC0020485/2021     	       N content too high	0.33
#
# USA/OH-CDC-LC0020543/2021     	       N content too high	0.47
#
# USA/MA-CDC-LC0020727/2021     	       N content too high	0.43
#
# USA/KY-CDC-LC0021414/2021     	       N content too high	0.37
#
# USA/NH-CDC-LC0022130/2021     	       N content too high	0.46
#
# OB998248                      	       N content too high	0.43
#
# Switzerland/SO-ETHZ-510694/2020	       N content too high	0.32
#
# USA/VA-CDC-LC0020675/2021     	       N content too high	0.43
#
# USA/MD-CDC-LC0020972/2021     	       N content too high	0.4
#
# USA/NH-CDC-LC0021313/2021     	       N content too high	0.42
#
# USA/NY-CDC-LC0022040/2021     	       N content too high	0.4
#
# USA/MA-CDC-LC0022106/2021     	       N content too high	0.36
#
# USA/NY-CDC-LC0022194/2021     	       N content too high	0.37
#
# USA/NY-CDC-LC0022416/2021     	       N content too high	0.34
#
# USA/NJ-CDC-LC0022614/2021     	       N content too high	0.49
#
# USA/TX-CDC-LC0024699/2021     	       N content too high	0.47
#
# USA/PA-CDC-LC0023395/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0023560/2021     	       N content too high	0.4
#
# OU030150                      	       N content too high	0.49
#
# USA/LA-CDC-LC0020922/2021     	       N content too high	0.4
#
# USA/UT-CDC-LC0024547/2021     	       N content too high	0.43
#
# USA/CA-CDC-LC0024433/2021     	       N content too high	0.46
#
# USA/NJ-CDC-LC0021831/2021     	       N content too high	0.32
#
# USA/NJ-CDC-LC0022213/2021     	       N content too high	0.37
#
# USA/IN-CDC-LC0023351/2021     	       N content too high	0.4
#
# USA/KY-CDC-LC0023067/2021     	       N content too high	0.47
#
# OU393264                      	       N content too high	0.49
#
# USA/FL-CDC-LC0021136/2021     	       N content too high	0.37
#
# USA/OH-CDC-LC0022028/2021     	       N content too high	0.4
#
# USA/PA-CDC-LC0021902/2021     	       N content too high	0.4
#
# OU389575                      	       N content too high	0.48
#
# OU420691                      	       N content too high	0.49
#
# USA/MA-CDC-LC0021819/2021     	       N content too high	0.36
#
# USA/NY-CDC-LC0021920/2021     	       N content too high	0.34
#
# USA/GA-CDC-LC0021329/2021     	       N content too high	0.36
#
# USA/NC-CDC-LC0022763/2021     	       N content too high	0.39
#
# USA/WV-CDC-LC0024187/2021     	       N content too high	0.46
#
# USA/CA-CDC-LC0024289/2021     	       N content too high	0.36
#
# USA/PA-CDC-LC0021746/2021     	       N content too high	0.36
#
# USA/NH-CDC-LC0021883/2021     	       N content too high	0.33
#
# USA/VA-CDC-LC0022180/2021     	       N content too high	0.37
#
# USA/NC-CDC-LC0022253/2021     	       N content too high	0.47
#
# USA/CA-CDC-LC0024067/2021     	       N content too high	0.4
#
# USA/NC-CDC-LC0021362/2021     	       N content too high	0.43
#
# USA/VA-CDC-LC0021494/2021     	       N content too high	0.4
#
# USA/GA-CDC-LC0021673/2021     	       N content too high	0.46
#
# USA/IL-CDC-LC0023998/2021     	       N content too high	0.42
#
# USA/CA-CDC-LC0026699/2021     	       N content too high	0.36
#
# USA/WV-CDC-LC0027147/2021     	       N content too high	0.41
#
# USA/FL-CDC-LC0023360/2021     	       N content too high	0.4
#
# OB997954                      	       N content too high	0.39
#
# USA/FL-CDC-LC0023021/2021     	       N content too high	0.47
#
# USA/LA-CDC-LC0023098/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0023103/2021     	       N content too high	0.4
#
# USA/RI-CDC-LC0023789/2021     	       N content too high	0.47
#
# USA/NY-CDC-LC0023650/2021     	       N content too high	0.4
#
# USA/CA-CDC-LC0026151/2021     	       N content too high	0.47
#
# USA/NH-CDC-LC0023382/2021     	       N content too high	0.33
#
# USA/MA-CDC-LC0023584/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0025684/2021     	       N content too high	0.36
#
# USA/NJ-CDC-LC0025538/2021     	       N content too high	0.37
#
# USA/OH-CDC-LC0025304/2021     	       N content too high	0.45
#
# USA/NY-CDC-LC0025748/2021     	       N content too high	0.33
#
# USA/PA-CDC-LC0025919/2021     	       N content too high	0.46
#
# USA/NJ-CDC-LC0026086/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0026492/2021     	       N content too high	0.46
#
# USA/MD-CDC-LC0027541/2021     	       N content too high	0.48
#
# USA/CA-CDC-LC0027849/2021     	       N content too high	0.49
#
# USA/NY-CDC-LC0027171/2021     	       N content too high	0.4
#
# USA/MD-CDC-LC0027806/2021     	       N content too high	0.43
#
# USA/WV-CDC-LC0026455/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0027131/2021     	       N content too high	0.32
#
# USA/NJ-CDC-LC0026907/2021     	       N content too high	0.36
#
# OU389229                      	       N content too high	0.42
#
# USA/FL-CDC-LC0025043/2021     	       N content too high	0.4
#
# USA/NY-CDC-LC0025143/2021     	       N content too high	0.33
#
# USA/MA-CDC-LC0025014/2021     	       N content too high	0.43
#
# USA/NC-CDC-LC0025338/2021     	       N content too high	0.44
#
# USA/MD-CDC-LC0026052/2021     	       N content too high	0.33
#
# USA/OK-CDC-LC0026025/2021     	       N content too high	0.36
#
# USA/PA-CDC-LC0026951/2021     	       N content too high	0.4
#
# USA/NY-CDC-LC0024869/2021     	       N content too high	0.33
#
# USA/CA-CDC-LC0027775/2021     	       N content too high	0.49
#
# USA/VA-CDC-LC0026088/2021     	       N content too high	0.32
#
# USA/NH-CDC-LC0025114/2021     	       N content too high	0.36
#
# USA/DC-CDC-LC0025929/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0025839/2021     	       N content too high	0.47
#
# USA/MD-CDC-LC0026198/2021     	       N content too high	0.36
#
# USA/CA-CDC-LC0026026/2021     	       N content too high	0.35
#
# USA/PA-CDC-LC0026510/2021     	       N content too high	0.33
#
# USA/FL-CDC-LC0026353/2021     	       N content too high	0.39
#
# OU389527                      	       N content too high	0.41
#
# USA/NJ-CDC-LC0027895/2021     	       N content too high	0.37
#
# USA/NC-CDC-LC0028940/2021     	       N content too high	0.37
#
# USA/NH-CDC-LC0029394/2021     	       N content too high	0.46
#
# USA/MA-CDC-LC0028890/2021     	       N content too high	0.43
#
# USA/FL-CDC-LC0029374/2021     	       N content too high	0.39
#
# USA/NH-CDC-LC0029312/2021     	       N content too high	0.47
#
# USA/LA-CDC-LC0029279/2021     	       N content too high	0.43
#
# USA/NC-CDC-LC0030926/2021     	       N content too high	0.43
#
# USA/MD-CDC-LC0030854/2021     	       N content too high	0.39
#
# OU029397                      	       N content too high	0.4
#
# Estonia/Cov10253/2021         	       N content too high	0.39
#
# USA/GA-CDC-LC0025717/2021     	       N content too high	0.32
#
# USA/GA-CDC-LC0025756/2021     	       N content too high	0.43
#
# USA/NJ-CDC-LC0028288/2021     	       N content too high	0.36
#
# USA/NJ-CDC-LC0028209/2021     	       N content too high	0.45
#
# USA/MA-CDC-LC0029097/2021     	       N content too high	0.46
#
# USA/MA-CDC-LC0029000/2021     	       N content too high	0.39
#
# USA/NY-CDC-LC0028293/2021     	       N content too high	0.4
#
# OB998097                      	       N content too high	0.32
#
# USA/OH-CDC-LC0028153/2021     	       N content too high	0.47
#
# USA/IN-CDC-LC0028648/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0028725/2021     	       N content too high	0.4
#
# USA/VA-CDC-LC0030878/2021     	       N content too high	0.49
#
# USA/IN-CDC-LC0028348/2021     	       N content too high	0.36
#
# USA/WV-CDC-LC0030473/2021     	       N content too high	0.46
#
# USA/NJ-CDC-LC0030633/2021     	       N content too high	0.39
#
# USA/NC-CDC-LC0030896/2021     	       N content too high	0.39
#
# USA/RI-CDC-LC0031634/2021     	       N content too high	0.35
#
# USA/NC-CDC-LC0029622/2021     	       N content too high	0.43
#
# USA/MD-CDC-LC0029553/2021     	       N content too high	0.46
#
# USA/NJ-CDC-LC0030511/2021     	       N content too high	0.32
#
# USA/MA-CDC-LC0031307/2021     	       N content too high	0.32
#
# OU347830                      	       N content too high	0.5
#
# USA/LA-CDC-LC0030371/2021     	       N content too high	0.36
#
# USA/FL-CDC-LC0029824/2021     	       N content too high	0.43
#
# OU348036                      	       N content too high	0.39
#
# Estonia/Cov10949/2021         	       N content too high	0.36
#
# USA/UND-00114482/2021         	       N content too high	0.41
#
# Estonia/Cov11162/2021         	       N content too high	0.43
#
# Estonia/Cov11013/2021         	       N content too high	0.42
#
# OU348363                      	       N content too high	0.48
#
# Switzerland/BL-ETHZ-591130/2021	       N content too high	0.31
#
# USA/UT-UPHL-210721739224/2021 	       N content too high	0.33
#
# OU388077                      	       N content too high	0.32
#
# OU384928                      	       N content too high	0.43
#
# MMR/DSMRC_018/2021            	            Seq too short	21988
#
# OU348033                      	       N content too high	0.5
#
# OU385109                      	       N content too high	0.39
#
# Switzerland/TI-EOC-022_25873632/2021	       N content too high	0.41
#
# OU385338                      	       N content too high	0.38
#
# OU491145                      	       N content too high	0.45
#
# OU387751                      	       N content too high	0.31
#
# OU393287                      	       N content too high	0.4
#
# OU418886                      	       N content too high	0.37
#
# OU419618                      	       N content too high	0.35
#
# OU421153                      	       N content too high	0.43
#
# OU422762                      	       N content too high	0.48
#
# OU394814                      	       N content too high	0.46
#
# OU390240                      	       N content too high	0.35
#
# MMR/DSMRC_015/2021            	            Seq too short	21990
#
# OU347886                      	       N content too high	0.34
#
# OU348142                      	       N content too high	0.43
#
# OU396260                      	       N content too high	0.31
#
# loading model 09/08/2021, 13:59:14
# processing block of 1000 sequences 09/08/2021, 13:59:29
# processing block of 1000 sequences 09/08/2021, 13:59:57
# processing block of 1000 sequences 09/08/2021, 14:00:23
# processing block of 1000 sequences 09/08/2021, 14:00:50
# processing block of 1000 sequences 09/08/2021, 14:01:17
# processing block of 1000 sequences 09/08/2021, 14:01:44
# processing block of 1000 sequences 09/08/2021, 14:02:11
# processing block of 1000 sequences 09/08/2021, 14:02:38
# processing block of 1000 sequences 09/08/2021, 14:03:04
# processing block of 1000 sequences 09/08/2021, 14:03:30
# processing block of 1000 sequences 09/08/2021, 14:03:55
# processing block of 1000 sequences 09/08/2021, 14:04:21
# processing block of 1000 sequences 09/08/2021, 14:04:45
# processing block of 1000 sequences 09/08/2021, 14:05:10
# processing block of 1000 sequences 09/08/2021, 14:05:35
# processing block of 1000 sequences 09/08/2021, 14:06:02
# processing block of 1000 sequences 09/08/2021, 14:06:28
# processing block of 1000 sequences 09/08/2021, 14:06:55
# processing block of 1000 sequences 09/08/2021, 14:07:20
# processing block of 1000 sequences 09/08/2021, 14:07:45
# processing block of 1000 sequences 09/08/2021, 14:08:11
# processing block of 1000 sequences 09/08/2021, 14:08:36
# processing block of 1000 sequences 09/08/2021, 14:09:01
# processing block of 1000 sequences 09/08/2021, 14:09:26
# processing block of 1000 sequences 09/08/2021, 14:09:52
# processing block of 1000 sequences 09/08/2021, 14:10:16
# processing block of 1000 sequences 09/08/2021, 14:10:42
# processing block of 1000 sequences 09/08/2021, 14:11:08
# processing block of 1000 sequences 09/08/2021, 14:11:32
# processing block of 1000 sequences 09/08/2021, 14:11:58
# processing block of 1000 sequences 09/08/2021, 14:12:23
# processing block of 1000 sequences 09/08/2021, 14:12:49
# processing block of 1000 sequences 09/08/2021, 14:13:14
# processing block of 1000 sequences 09/08/2021, 14:13:40
# processing block of 1000 sequences 09/08/2021, 14:14:05
# processing block of 1000 sequences 09/08/2021, 14:14:31
# processing block of 1000 sequences 09/08/2021, 14:14:54
# processing block of 1000 sequences 09/08/2021, 14:15:18
# processing block of 1000 sequences 09/08/2021, 14:15:42
# processing block of 1000 sequences 09/08/2021, 14:16:07
# processing block of 1000 sequences 09/08/2021, 14:16:32
# processing block of 1000 sequences 09/08/2021, 14:16:58
# processing block of 1000 sequences 09/08/2021, 14:17:22
# processing block of 1000 sequences 09/08/2021, 14:17:48
# processing block of 1000 sequences 09/08/2021, 14:18:15
# processing block of 1000 sequences 09/08/2021, 14:18:42
# processing block of 1000 sequences 09/08/2021, 14:19:07
# processing block of 1000 sequences 09/08/2021, 14:19:33
# processing block of 1000 sequences 09/08/2021, 14:19:58
# processing block of 1000 sequences 09/08/2021, 14:20:23
# processing block of 1000 sequences 09/08/2021, 14:20:48
# processing block of 1000 sequences 09/08/2021, 14:21:14
# processing block of 1000 sequences 09/08/2021, 14:21:40
# processing block of 1000 sequences 09/08/2021, 14:22:08
# processing block of 1000 sequences 09/08/2021, 14:22:36
# processing block of 1000 sequences 09/08/2021, 14:23:01
# processing block of 1000 sequences 09/08/2021, 14:23:26
# processing block of 1000 sequences 09/08/2021, 14:23:50
# processing block of 1000 sequences 09/08/2021, 14:24:16
# processing block of 1000 sequences 09/08/2021, 14:24:41
# processing block of 1000 sequences 09/08/2021, 14:25:07
# processing block of 1000 sequences 09/08/2021, 14:25:32
# processing block of 1000 sequences 09/08/2021, 14:25:57
# processing block of 1000 sequences 09/08/2021, 14:26:27
# processing block of 1000 sequences 09/08/2021, 14:26:52
# processing block of 1000 sequences 09/08/2021, 14:27:18
# processing block of 1000 sequences 09/08/2021, 14:27:44
# processing block of 1000 sequences 09/08/2021, 14:28:08
# processing block of 1000 sequences 09/08/2021, 14:28:33
# processing block of 1000 sequences 09/08/2021, 14:28:57
# processing block of 1000 sequences 09/08/2021, 14:29:21
# processing block of 123 sequences 09/08/2021, 14:29:36
# complete 09/08/2021, 14:29:38
# Output file written to: /home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/pangolin/lineage_report.csv
# OU419433                      	       N content too high	0.33
#
# OU386053                      	       N content too high	0.32
#
# OU392144                      	       N content too high	0.32
#
# OU393754                      	       N content too high	0.44
#
# OU347666                      	       N content too high	0.49
#
# OU348278                      	       N content too high	0.35
#
# OU348522                      	       N content too high	0.45
#
# OU423482                      	       N content too high	0.36
#
# OU391500                      	       N content too high	0.42
#
# OU393923                      	       N content too high	0.45
#
# OU419875                      	       N content too high	0.39
#
# OU418931                      	       N content too high	0.4
#
# OU422240                      	       N content too high	0.31
#
# OU489782                      	       N content too high	0.36
#
# OU447558                      	       N content too high	0.46
#
# OU447876                      	       N content too high	0.4
#
# OU487939                      	       N content too high	0.35
#
# OU490115                      	       N content too high	0.32
#
# OU490737                      	       N content too high	0.49
#
# Switzerland/TI-EOC-42_26026293/2021	       N content too high	0.4
#
# OU488276                      	       N content too high	0.4
#
# OU490899                      	       N content too high	0.35
#
# OU447098                      	       N content too high	0.5
#
# OU448246                      	       N content too high	0.46
#
# OU447486                      	       N content too high	0.45
#
# OU490398                      	       N content too high	0.47
#
# OU492041                      	       N content too high	0.46
#
# OU489903                      	       N content too high	0.4
#
# OU488237                      	       N content too high	0.44
#
# OU488719                      	       N content too high	0.45
#
# OU488942                      	       N content too high	0.44
#
# OU489080                      	       N content too high	0.43
#
# OU489512                      	       N content too high	0.46
#
# OU491783                      	       N content too high	0.44
#
# OU488574                      	       N content too high	0.43
#
# OU488207                      	       N content too high	0.41
#
# OU490562                      	       N content too high	0.47
#
# OU490569                      	       N content too high	0.45
#
# OU490836                      	       N content too high	0.31
#
# USA/D4F17D14A7C44B168CD47F1B0D34ADB7/2021	       N content too high	0.32
#
#
# Number of sequences detected: 100000
# Total passing QC: 99492
#
# Data files found:
# Trained model:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTree_v1.joblib
# Header file:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTreeHeaders_v1.joblib
# Designated hash:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/lineages.hash.csv
#
# Job stats:
# job                     count    min threads    max threads
# --------------------  -------  -------------  -------------
# add_failed_seqs             1              1              1
# align_to_reference          1              1              1
# all                         1              1              1
# generate_report             1              1              1
# get_constellations          1              1              1
# hash_sequence_assign        1              1              1
# pangolearn                  1              1              1
# scorpio                     1             52             52
# total                       8              1             52
#
# /home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # 3. Load up and join pangolin to metadata
#
# ## 3.1. Load pangolin results

# %%
import pandas as pd

pangolin_report = pangolin_out_dir / 'lineage_report.csv'

p_df = pd.read_csv(pangolin_report)
p_df
# Out:
#                                            taxon lineage  conflict  \
# 0                       Wuhan/IPBCAMS-WH-04/2019       B       NaN
# 1                        CHN/Wuhan_IME-WH05/2019       B       NaN
# 2                        Switzerland/100108/2020     B.1       NaN
# 3                        Switzerland/100816/2020     B.1       NaN
# 4                                       LR862442    C.35       NaN
# ...                                          ...     ...       ...
# 99995                                   OU488207    None       NaN
# 99996                                   OU490562    None       NaN
# 99997                                   OU490569    None       NaN
# 99998                                   OU490836    None       NaN
# 99999  USA/D4F17D14A7C44B168CD47F1B0D34ADB7/2021    None       NaN
#
#        ambiguity_score scorpio_call  scorpio_support  scorpio_conflict  \
# 0                  NaN          NaN              NaN               NaN
# 1                  NaN          NaN              NaN               NaN
# 2                  NaN          NaN              NaN               NaN
# 3                  NaN          NaN              NaN               NaN
# 4                  NaN          NaN              NaN               NaN
# ...                ...          ...              ...               ...
# 99995              NaN          NaN              NaN               NaN
# 99996              NaN          NaN              NaN               NaN
# 99997              NaN          NaN              NaN               NaN
# 99998              NaN          NaN              NaN               NaN
# 99999              NaN          NaN              NaN               NaN
#
#              version pangolin_version pangoLEARN_version pango_version  \
# 0      PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 1      PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 2      PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 3      PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 4      PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# ...              ...              ...                ...           ...
# 99995  PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99996  PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99997  PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99998  PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99999  PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
#
#           status                             note
# 0      passed_qc  Assigned from designation hash.
# 1      passed_qc  Assigned from designation hash.
# 2      passed_qc  Assigned from designation hash.
# 3      passed_qc  Assigned from designation hash.
# 4      passed_qc  Assigned from designation hash.
# ...          ...                              ...
# 99995       fail                   N_content:0.41
# 99996       fail                   N_content:0.47
# 99997       fail                   N_content:0.45
# 99998       fail                   N_content:0.31
# 99999       fail                   N_content:0.32
#
# [100000 rows x 13 columns]

# %% [markdown]
# ## 3.2. Load other metadata

# %%
import pandas as pd

metadata_df = pd.read_csv(subset_metadata_path, sep='\t')
metadata_df
# Out:
#                                  strain virus   gisaid_epi_isl  \
# 0                              OU420663  ncov                ?
# 1             USA/NY-CUIMC-NP-3606/2020  ncov                ?
# 2      Switzerland/BL-UHB-42491849/2020  ncov   EPI_ISL_930932
# 3            Scotland/QEUH-1618558/2021  ncov  EPI_ISL_2487678
# 4            Scotland/QEUH-16829C6/2021  ncov  EPI_ISL_2554507
# ...                                 ...   ...              ...
# 99995       USA/OH-CDC-QDX23654955/2021  ncov  EPI_ISL_1669162
# 99996         USA/KS-CDC-LC0014845/2021  ncov  EPI_ISL_1255089
# 99997                 USA/WA-S5065/2020  ncov  EPI_ISL_1114222
# 99998         England/MILK-10AE881/2021  ncov   EPI_ISL_993691
# 99999          England/ALDP-B5B038/2020  ncov   EPI_ISL_655604
#
#       genbank_accession sra_accession        date         region  \
# 0              OU420663    ERR5939958        2020         Europe
# 1              MZ702266           NaN  2020-12-02  North America
# 2              OU281100           NaN  2020-10-18         Europe
# 3              OU314699    ERR6069165  2021-06-02         Europe
# 4              OU329920    ERR6085250  2021-06-10         Europe
# ...                 ...           ...         ...            ...
# 99995          MW989219           NaN  2021-04-05  North America
# 99996          MW704675           NaN  2021-02-09  North America
# 99997          MW689132           NaN  2020-11-06  North America
# 99998          OD978562    ERR5303908  2021-01-17         Europe
# 99999          OB997017    ERR4877748  2020-11-08         Europe
#
#               country    division             location  ... divergence  \
# 0      United Kingdom     England                  NaN  ...       40.0
# 1                 USA    New York        New York City  ...       21.0
# 2         Switzerland  Basel-Land                  NaN  ...       19.0
# 3      United Kingdom    Scotland                  NaN  ...       33.0
# 4      United Kingdom    Scotland                  NaN  ...       37.0
# ...               ...         ...                  ...  ...        ...
# 99995             USA        Ohio                  NaN  ...       35.0
# 99996             USA      Kansas                  NaN  ...       21.0
# 99997             USA  Washington  Grays Harbor County  ...       14.0
# 99998  United Kingdom     England                  NaN  ...       32.0
# 99999  United Kingdom     England                  NaN  ...       16.0
#
#       nonACGTN rare_mutations snp_clusters  QC_missing_data QC_mixed_sites  \
# 0          0.0           15.0          0.0             good           good
# 1          0.0            7.0          0.0         mediocre           good
# 2          0.0            6.0          0.0             good           good
# 3          0.0            7.0          0.0         mediocre           good
# 4          0.0            5.0          0.0             good           good
# ...        ...            ...          ...              ...            ...
# 99995      0.0            9.0          0.0             good           good
# 99996      0.0            6.0          0.0             good           good
# 99997      0.0            0.0          0.0             good           good
# 99998      0.0            7.0          0.0             good           good
# 99999      0.0            3.0          0.0             good           good
#
#       QC_rare_mutations QC_snp_clusters clock_deviation missing_data_percent
# 0                  good            good               ?             0.351135
# 1                  good            good             0.0             4.417617
# 2                  good            good             0.0             0.297629
# 3                  good            good            -5.0             3.885898
# 4                  good            good             1.0             0.404642
# ...                 ...             ...             ...                  ...
# 99995              good            good             0.0             0.000000
# 99996              good            good            -2.0             3.394308
# 99997              good            good            -2.0             0.006688
# 99998              good            good             0.0             1.595158
# 99999              good            good            -1.0             2.324182
#
# [100000 rows x 40 columns]

# %%
metadata_df.columns
# Out:
# Index(['strain', 'virus', 'gisaid_epi_isl', 'genbank_accession',
#        'sra_accession', 'date', 'region', 'country', 'division', 'location',
#        'region_exposure', 'country_exposure', 'division_exposure', 'segment',
#        'length', 'host', 'age', 'sex', 'Nextstrain_clade', 'pango_lineage',
#        'GISAID_clade', 'originating_lab', 'submitting_lab', 'authors', 'url',
#        'title', 'paper_url', 'date_submitted', 'sampling_strategy',
#        'missing_data', 'divergence', 'nonACGTN', 'rare_mutations',
#        'snp_clusters', 'QC_missing_data', 'QC_mixed_sites',
#        'QC_rare_mutations', 'QC_snp_clusters', 'clock_deviation',
#        'missing_data_percent'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Join to pangolin results

# %%
metadata_pangolin_df = metadata_df.merge(p_df, left_on='strain', right_on='taxon')
metadata_pangolin_df
# Out:
#                                  strain virus   gisaid_epi_isl  \
# 0                              OU420663  ncov                ?
# 1             USA/NY-CUIMC-NP-3606/2020  ncov                ?
# 2      Switzerland/BL-UHB-42491849/2020  ncov   EPI_ISL_930932
# 3            Scotland/QEUH-1618558/2021  ncov  EPI_ISL_2487678
# 4            Scotland/QEUH-16829C6/2021  ncov  EPI_ISL_2554507
# ...                                 ...   ...              ...
# 99995       USA/OH-CDC-QDX23654955/2021  ncov  EPI_ISL_1669162
# 99996         USA/KS-CDC-LC0014845/2021  ncov  EPI_ISL_1255089
# 99997                 USA/WA-S5065/2020  ncov  EPI_ISL_1114222
# 99998         England/MILK-10AE881/2021  ncov   EPI_ISL_993691
# 99999          England/ALDP-B5B038/2020  ncov   EPI_ISL_655604
#
#       genbank_accession sra_accession        date         region  \
# 0              OU420663    ERR5939958        2020         Europe
# 1              MZ702266           NaN  2020-12-02  North America
# 2              OU281100           NaN  2020-10-18         Europe
# 3              OU314699    ERR6069165  2021-06-02         Europe
# 4              OU329920    ERR6085250  2021-06-10         Europe
# ...                 ...           ...         ...            ...
# 99995          MW989219           NaN  2021-04-05  North America
# 99996          MW704675           NaN  2021-02-09  North America
# 99997          MW689132           NaN  2020-11-06  North America
# 99998          OD978562    ERR5303908  2021-01-17         Europe
# 99999          OB997017    ERR4877748  2020-11-08         Europe
#
#               country    division             location  ... ambiguity_score  \
# 0      United Kingdom     England                  NaN  ...        1.000000
# 1                 USA    New York        New York City  ...        0.950970
# 2         Switzerland  Basel-Land                  NaN  ...             NaN
# 3      United Kingdom    Scotland                  NaN  ...        0.967377
# 4      United Kingdom    Scotland                  NaN  ...             NaN
# ...               ...         ...                  ...  ...             ...
# 99995             USA        Ohio                  NaN  ...        1.000000
# 99996             USA      Kansas                  NaN  ...        0.969668
# 99997             USA  Washington  Grays Harbor County  ...        0.999926
# 99998  United Kingdom     England                  NaN  ...             NaN
# 99999  United Kingdom     England                  NaN  ...             NaN
#
#                  scorpio_call scorpio_support scorpio_conflict  \
# 0        Alpha (B.1.1.7-like)          1.0000           0.0000
# 1                         NaN             NaN              NaN
# 2                         NaN             NaN              NaN
# 3        Alpha (B.1.1.7-like)          0.8261           0.0435
# 4      Delta (B.1.617.2-like)          1.0000           0.0000
# ...                       ...             ...              ...
# 99995    Alpha (B.1.1.7-like)          0.9565           0.0435
# 99996                     NaN             NaN              NaN
# 99997                     NaN             NaN              NaN
# 99998    Alpha (B.1.1.7-like)          0.9565           0.0435
# 99999                     NaN             NaN              NaN
#
#               version pangolin_version pangoLEARN_version pango_version  \
# 0      PLEARN-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 1      PLEARN-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 2       PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 3      PLEARN-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 4       PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# ...               ...              ...                ...           ...
# 99995  PLEARN-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99996  PLEARN-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99997  PLEARN-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99998   PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
# 99999   PANGO-v1.2.66           3.1.11         2021-08-24       v1.2.66
#
#           status                                               note
# 0      passed_qc  scorpio call: Alt alleles 23; Ref alleles 0; A...
# 1      passed_qc                                                NaN
# 2      passed_qc                    Assigned from designation hash.
# 3      passed_qc  scorpio call: Alt alleles 19; Ref alleles 1; A...
# 4      passed_qc  scorpio call: Alt alleles 13; Ref alleles 0; A...
# ...          ...                                                ...
# 99995  passed_qc  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 99996  passed_qc                                                NaN
# 99997  passed_qc                                                NaN
# 99998  passed_qc  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 99999  passed_qc                    Assigned from designation hash.
#
# [100000 rows x 53 columns]

# %% [markdown]
# # 4. Save joined metadata to file

# %%
metadata_pangolin_df.to_csv(output_metadata_pangolin_path, sep='\t', index=False)

print(f'Saved metadata and pangolin to {output_metadata_pangolin_path}')
# Out:
# Saved metadata and pangolin to input/metadata-subsample-pangolin.tsv
