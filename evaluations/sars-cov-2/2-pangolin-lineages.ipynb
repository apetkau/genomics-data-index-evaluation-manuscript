# %% [markdown]
# # 1. Parameters

# %%
sequences_split_dir = 'input/split'
sequences_subset_all = 'input/all.fasta.gz'
pangolin_out_dir = 'input/pangolin'
subset_metadata_path = 'input/metadata-subsample.tsv'
output_metadata_pangolin_path = 'input/metadata-subsample-pangolin.tsv'

# %%
from pathlib import Path

sequences_split_dir = Path(sequences_split_dir)
sequences_subset_all = Path(sequences_subset_all)
pangolin_out_dir = Path(pangolin_out_dir)
subset_metadata_path = Path(subset_metadata_path)
output_metadata_pangolin_path = Path(output_metadata_pangolin_path)

# %% [markdown]
# # 2. Run pangolin

# %%
# !conda run --name pangolin pangolin --all-versions
# Out:
# pangolin: 3.1.11
# pangolearn: 2021-08-24
# constellations: v0.0.15
# scorpio: 0.3.12
# pango-designation: 1.2.76

# %%
# !conda run --name pangolin pangolin -t 52 -o {pangolin_out_dir} {sequences_subset_all}
# Out:
# loading model 09/07/2021, 21:27:17
# processing block of 1000 sequences 09/07/2021, 21:27:28
# processing block of 1000 sequences 09/07/2021, 21:27:57
# processing block of 1000 sequences 09/07/2021, 21:28:21
# processing block of 1000 sequences 09/07/2021, 21:28:45
# processing block of 1000 sequences 09/07/2021, 21:29:08
# processing block of 1000 sequences 09/07/2021, 21:29:32
# processing block of 1000 sequences 09/07/2021, 21:29:55
# processing block of 139 sequences 09/07/2021, 21:30:10
# complete 09/07/2021, 21:30:13
# Output file written to: /home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/pangolin/lineage_report.csv
# All dependencies satisfied.
# The query file is:/home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/all.fasta.gz
# ** Sequence QC **
# Sequence name                 	                   Reason	Value
#
#
# Number of sequences detected: 10000
# Total passing QC: 10000
#
# Data files found:
# Trained model:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTree_v1.joblib
# Header file:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTreeHeaders_v1.joblib
# Designated hash:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/lineages.hash.csv
#
# Job stats:
# job                     count    min threads    max threads
# --------------------  -------  -------------  -------------
# add_failed_seqs             1              1              1
# align_to_reference          1              1              1
# all                         1              1              1
# generate_report             1              1              1
# get_constellations          1              1              1
# hash_sequence_assign        1              1              1
# pangolearn                  1              1              1
# scorpio                     1             52             52
# total                       8              1             52
#
# /home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # 3. Load up and join pangolin to metadata
#
# ## 3.1. Load pangolin results

# %%
import pandas as pd

pangolin_report = pangolin_out_dir / 'lineage_report.csv'

p_df = pd.read_csv(pangolin_report)
p_df
# Out:
#          taxon     lineage  conflict  ambiguity_score          scorpio_call  \
# 0     LR862463        C.35       NaN              NaN                   NaN
# 1     LR882087  B.1.177.23       NaN              NaN                   NaN
# 2     LR882100    B.1.1.70       NaN              NaN                   NaN
# 3     LR882436    B.1.1.39       NaN              NaN                   NaN
# 4     LR882838       B.1.1       NaN              NaN                   NaN
# ...        ...         ...       ...              ...                   ...
# 9995  OU149351     B.1.1.7       0.0         0.999851  Alpha (B.1.1.7-like)
# 9996  OU149407     B.1.1.7       0.0         0.992859  Alpha (B.1.1.7-like)
# 9997  OU149436     B.1.1.7       0.0         0.999666  Alpha (B.1.1.7-like)
# 9998  OU149604     B.1.1.7       0.0         1.000000  Alpha (B.1.1.7-like)
# 9999  OU149613     B.1.1.7       0.0         1.000000  Alpha (B.1.1.7-like)
#
#       scorpio_support  scorpio_conflict         version pangolin_version  \
# 0                 NaN               NaN   PANGO-v1.2.66           3.1.11
# 1                 NaN               NaN   PANGO-v1.2.66           3.1.11
# 2                 NaN               NaN   PANGO-v1.2.66           3.1.11
# 3                 NaN               NaN   PANGO-v1.2.66           3.1.11
# 4                 NaN               NaN   PANGO-v1.2.66           3.1.11
# ...               ...               ...             ...              ...
# 9995           0.9565            0.0435  PLEARN-v1.2.66           3.1.11
# 9996           0.9565            0.0435  PLEARN-v1.2.66           3.1.11
# 9997           0.8696            0.0435  PLEARN-v1.2.66           3.1.11
# 9998           0.9565            0.0435  PLEARN-v1.2.66           3.1.11
# 9999           0.9565            0.0435  PLEARN-v1.2.66           3.1.11
#
#      pangoLEARN_version pango_version     status  \
# 0            2021-08-24       v1.2.66  passed_qc
# 1            2021-08-24       v1.2.66  passed_qc
# 2            2021-08-24       v1.2.66  passed_qc
# 3            2021-08-24       v1.2.66  passed_qc
# 4            2021-08-24       v1.2.66  passed_qc
# ...                 ...           ...        ...
# 9995         2021-08-24       v1.2.66  passed_qc
# 9996         2021-08-24       v1.2.66  passed_qc
# 9997         2021-08-24       v1.2.66  passed_qc
# 9998         2021-08-24       v1.2.66  passed_qc
# 9999         2021-08-24       v1.2.66  passed_qc
#
#                                                    note
# 0                       Assigned from designation hash.
# 1                       Assigned from designation hash.
# 2                       Assigned from designation hash.
# 3                       Assigned from designation hash.
# 4                       Assigned from designation hash.
# ...                                                 ...
# 9995  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9996  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9997  scorpio call: Alt alleles 20; Ref alleles 1; A...
# 9998  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9999  scorpio call: Alt alleles 22; Ref alleles 1; A...
#
# [10000 rows x 13 columns]

# %% [markdown]
# ## 3.2. Load other metadata

# %%
import pandas as pd

metadata_df = pd.read_csv(subset_metadata_path, sep='\t')
metadata_df
# Out:
#                                strain virus   gisaid_epi_isl  \
# 0           England/QEUH-148725F/2021  ncov  EPI_ISL_1487327
# 1           England/MILK-1535AC0/2021  ncov  EPI_ISL_1985652
# 2            England/QEUH-789A28/2020  ncov   EPI_ISL_533176
# 3        USA/CA-CDC-ASC210034758/2021  ncov  EPI_ISL_2042505
# 4     Switzerland/ZH-ETHZ-500086/2020  ncov  EPI_ISL_1119047
# ...                               ...   ...              ...
# 9995                         OU201734  ncov                ?
# 9996        England/ALDP-18C9AA0/2021  ncov  EPI_ISL_2973222
# 9997        England/RAND-12BEEC6/2021  ncov  EPI_ISL_1070245
# 9998     USA/MA-CDC-ASC210073741/2021  ncov  EPI_ISL_2041225
# 9999        England/ALDP-1A019CB/2021  ncov  EPI_ISL_3168561
#
#      genbank_accession sra_accession        date         region  \
# 0             OU224813    ERR5679447  2021-03-28         Europe
# 1             OU266415    ERR5905912  2021-04-24         Europe
# 2             OA970628    ERR4584389  2020-07-15         Europe
# 3             MZ184110           NaN  2021-04-26  North America
# 4             OU011535           NaN  2020-11-09         Europe
# ...                ...           ...         ...            ...
# 9995          OU201734           NaN  2021-05-08         Europe
# 9996          OU436787    ERR6327095  2021-07-07         Europe
# 9997          OD996254    ERR5380596  2021-02-10         Europe
# 9998          MZ187570           NaN  2021-04-17  North America
# 9999          OU477474    ERR6403991  2021-07-23         Europe
#
#              country                division location  ... divergence  \
# 0     United Kingdom                 England      NaN  ...       34.0
# 1     United Kingdom                 England      NaN  ...       31.0
# 2     United Kingdom                 England      NaN  ...       14.0
# 3                USA              California      NaN  ...       37.0
# 4        Switzerland                  Zürich      NaN  ...       32.0
# ...              ...                     ...      ...  ...        ...
# 9995         Germany  North Rhine Westphalia      NaN  ...       32.0
# 9996  United Kingdom                 England      NaN  ...       39.0
# 9997  United Kingdom                 England      NaN  ...       30.0
# 9998             USA           Massachusetts      NaN  ...       37.0
# 9999  United Kingdom                 England      NaN  ...       38.0
#
#      nonACGTN rare_mutations snp_clusters  QC_missing_data QC_mixed_sites  \
# 0         0.0            9.0          0.0             good           good
# 1         0.0           10.0          0.0             good           good
# 2         0.0            7.0          0.0             good           good
# 3         0.0            7.0          0.0             good           good
# 4         0.0            7.0          0.0             good           good
# ...       ...            ...          ...              ...            ...
# 9995      3.0            8.0          0.0             good       mediocre
# 9996      0.0           10.0          0.0             good           good
# 9997      0.0            5.0          0.0             good           good
# 9998      0.0            8.0          0.0             good           good
# 9999      2.0            7.0          0.0             good           good
#
#      QC_rare_mutations QC_snp_clusters clock_deviation missing_data_percent
# 0                 good            good            -1.0             0.404642
# 1                 good            good             1.0             0.404642
# 2                 good            good             1.0             0.404642
# 3                 good            good             0.0             0.016721
# 4                 good            good             4.0             0.000000
# ...                ...             ...             ...                  ...
# 9995              good            good            -5.0             0.678862
# 9996              good            good             2.0             0.404642
# 9997              good            good            -2.0             0.404642
# 9998              good            good             0.0             0.000000
# 9999              good            good             0.0             2.651908
#
# [10000 rows x 40 columns]

# %%
metadata_df.columns
# Out:
# Index(['strain', 'virus', 'gisaid_epi_isl', 'genbank_accession',
#        'sra_accession', 'date', 'region', 'country', 'division', 'location',
#        'region_exposure', 'country_exposure', 'division_exposure', 'segment',
#        'length', 'host', 'age', 'sex', 'Nextstrain_clade', 'pango_lineage',
#        'GISAID_clade', 'originating_lab', 'submitting_lab', 'authors', 'url',
#        'title', 'paper_url', 'date_submitted', 'sampling_strategy',
#        'missing_data', 'divergence', 'nonACGTN', 'rare_mutations',
#        'snp_clusters', 'QC_missing_data', 'QC_mixed_sites',
#        'QC_rare_mutations', 'QC_snp_clusters', 'clock_deviation',
#        'missing_data_percent'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Join to pangolin results

# %%
metadata_pangolin_df = metadata_df.merge(p_df, left_on='strain', right_on='taxon')
metadata_pangolin_df
# Out:
#                                strain virus   gisaid_epi_isl  \
# 0           England/QEUH-148725F/2021  ncov  EPI_ISL_1487327
# 1           England/MILK-1535AC0/2021  ncov  EPI_ISL_1985652
# 2            England/QEUH-789A28/2020  ncov   EPI_ISL_533176
# 3        USA/CA-CDC-ASC210034758/2021  ncov  EPI_ISL_2042505
# 4     Switzerland/ZH-ETHZ-500086/2020  ncov  EPI_ISL_1119047
# ...                               ...   ...              ...
# 9995                         OU201734  ncov                ?
# 9996        England/ALDP-18C9AA0/2021  ncov  EPI_ISL_2973222
# 9997        England/RAND-12BEEC6/2021  ncov  EPI_ISL_1070245
# 9998     USA/MA-CDC-ASC210073741/2021  ncov  EPI_ISL_2041225
# 9999        England/ALDP-1A019CB/2021  ncov  EPI_ISL_3168561
#
#      genbank_accession sra_accession        date         region  \
# 0             OU224813    ERR5679447  2021-03-28         Europe
# 1             OU266415    ERR5905912  2021-04-24         Europe
# 2             OA970628    ERR4584389  2020-07-15         Europe
# 3             MZ184110           NaN  2021-04-26  North America
# 4             OU011535           NaN  2020-11-09         Europe
# ...                ...           ...         ...            ...
# 9995          OU201734           NaN  2021-05-08         Europe
# 9996          OU436787    ERR6327095  2021-07-07         Europe
# 9997          OD996254    ERR5380596  2021-02-10         Europe
# 9998          MZ187570           NaN  2021-04-17  North America
# 9999          OU477474    ERR6403991  2021-07-23         Europe
#
#              country                division location  ... ambiguity_score  \
# 0     United Kingdom                 England      NaN  ...        1.000000
# 1     United Kingdom                 England      NaN  ...        1.000000
# 2     United Kingdom                 England      NaN  ...             NaN
# 3                USA              California      NaN  ...        1.000000
# 4        Switzerland                  Zürich      NaN  ...        1.000000
# ...              ...                     ...      ...  ...             ...
# 9995         Germany  North Rhine Westphalia      NaN  ...        0.992369
# 9996  United Kingdom                 England      NaN  ...             NaN
# 9997  United Kingdom                 England      NaN  ...             NaN
# 9998             USA           Massachusetts      NaN  ...        1.000000
# 9999  United Kingdom                 England      NaN  ...        0.975857
#
#                 scorpio_call scorpio_support scorpio_conflict         version  \
# 0       Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# 1             B.1.1.318-like          0.8421           0.0000  PLEARN-v1.2.66
# 2                        NaN             NaN              NaN   PANGO-v1.2.66
# 3           Gamma (P.1-like)          0.8750           0.0000  PLEARN-v1.2.66
# 4       Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# ...                      ...             ...              ...             ...
# 9995    Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# 9996  Delta (B.1.617.2-like)          1.0000           0.0000   PANGO-v1.2.66
# 9997    Alpha (B.1.1.7-like)          0.9565           0.0435   PANGO-v1.2.66
# 9998    Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.66
# 9999  Delta (B.1.617.2-like)          1.0000           0.0000  PLEARN-v1.2.66
#
#      pangolin_version pangoLEARN_version pango_version     status  \
# 0              3.1.11         2021-08-24       v1.2.66  passed_qc
# 1              3.1.11         2021-08-24       v1.2.66  passed_qc
# 2              3.1.11         2021-08-24       v1.2.66  passed_qc
# 3              3.1.11         2021-08-24       v1.2.66  passed_qc
# 4              3.1.11         2021-08-24       v1.2.66  passed_qc
# ...               ...                ...           ...        ...
# 9995           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9996           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9997           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9998           3.1.11         2021-08-24       v1.2.66  passed_qc
# 9999           3.1.11         2021-08-24       v1.2.66  passed_qc
#
#                                                    note
# 0     scorpio call: Alt alleles 22; Ref alleles 1; A...
# 1     scorpio call: Alt alleles 16; Ref alleles 0; A...
# 2                       Assigned from designation hash.
# 3     scorpio call: Alt alleles 14; Ref alleles 0; A...
# 4     scorpio call: Alt alleles 22; Ref alleles 1; A...
# ...                                                 ...
# 9995  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9996  scorpio call: Alt alleles 13; Ref alleles 0; A...
# 9997  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9998  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9999  scorpio call: Alt alleles 13; Ref alleles 0; A...
#
# [10000 rows x 53 columns]

# %% [markdown]
# # 4. Save joined metadata to file

# %%
metadata_pangolin_df.to_csv(output_metadata_pangolin_path, sep='\t', index=False)

print(f'Saved metadata and pangolin to {output_metadata_pangolin_path}')
# Out:
# Saved metadata and pangolin to input/metadata-subsample-pangolin.tsv
