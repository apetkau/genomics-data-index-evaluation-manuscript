# %% [markdown]
# # 1. Parameters

# %%
sequences_split_dir = 'input/split'
sequences_subset_all = 'input/all.fasta.gz'
pangolin_out_dir = 'input/pangolin'
subset_metadata_path = 'input/metadata-subsample.tsv'
output_metadata_pangolin_path = 'input/metadata-subsample-pangolin.tsv'

# %%
from pathlib import Path

sequences_split_dir = Path(sequences_split_dir)
sequences_subset_all = Path(sequences_subset_all)
pangolin_out_dir = Path(pangolin_out_dir)
subset_metadata_path = Path(subset_metadata_path)
output_metadata_pangolin_path = Path(output_metadata_pangolin_path)

# %% [markdown]
# # 2. Run pangolin

# %%
# !conda run --name pangolin pangolin --all-versions
# Out:
# pangolin: 3.1.11
# pangolearn: 2021-08-24
# constellations: v0.0.15
# scorpio: 0.3.12
# pango-designation: 1.2.76

# %%
# !conda run --name pangolin pangolin -t 32 -o {pangolin_out_dir} {sequences_subset_all}
# Out:
# loading model 09/07/2021, 12:14:03
# processing block of 1000 sequences 09/07/2021, 12:14:17
# processing block of 1000 sequences 09/07/2021, 12:14:44
# processing block of 1000 sequences 09/07/2021, 12:15:11
# processing block of 1000 sequences 09/07/2021, 12:15:39
# processing block of 1000 sequences 09/07/2021, 12:16:06
# processing block of 1000 sequences 09/07/2021, 12:16:33
# processing block of 1000 sequences 09/07/2021, 12:16:59
# processing block of 174 sequences 09/07/2021, 12:17:17
# complete 09/07/2021, 12:17:20
# Output file written to: /home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/pangolin/lineage_report.csv
# All dependencies satisfied.
# The query file is:/home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/all.fasta.gz
# ** Sequence QC **
# Sequence name                 	                   Reason	Value
#
# LR898765                      	       N content too high	0.32
#
# OU489210                      	       N content too high	0.34
#
# OU489922                      	       N content too high	0.38
#
# OU491435                      	       N content too high	0.4
#
# LR991394                      	       N content too high	1.0
#
# LR991597                      	       N content too high	1.0
#
# OD917122                      	       N content too high	0.97
#
# Iceland/4113/2020             	       N content too high	0.36
#
# Iceland/6531/2020             	       N content too high	0.72
#
# Iceland/3971/2020             	       N content too high	0.41
#
# USA/CA-UCSC-500/2020          	       N content too high	0.36
#
# Iceland/5366/2020             	       N content too high	0.73
#
# HG996822                      	       N content too high	0.47
#
# OU418761                      	       N content too high	0.33
#
# USA/GA-CDC-LC0000982/2020     	       N content too high	0.43
#
# USA/GA-CDC-LC0001005/2020     	       N content too high	0.42
#
# USA/GA-CDC-LC0001977/2020     	       N content too high	0.36
#
# USA/KY-CDC-LC0004023/2021     	       N content too high	0.37
#
# USA/WI-CDC-LC0004091/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0004474/2021     	       N content too high	0.36
#
# OU029775                      	       N content too high	0.38
#
# USA/TN-CDC-LC0003613/2021     	       N content too high	0.32
#
# USA/CT-CDC-LC0003736/2021     	       N content too high	0.46
#
# USA/CA-Broad_FlowHealth-00017/2021	       N content too high	0.38
#
# USA/NJ-CDC-LC0006911/2021     	       N content too high	0.46
#
# OU031226                      	       N content too high	0.43
#
# USA/GA-CDC-LC0009522/2021     	       N content too high	0.43
#
# USA/NC-CDC-LC0010025/2021     	       N content too high	0.43
#
# USA/DC-CDC-LC0009545/2021     	       N content too high	0.34
#
# USA/NV-CDC-LC0011393/2021     	       N content too high	0.4
#
# USA/CA-CDC-LC0013605/2021     	       N content too high	0.4
#
# USA/KS-CDC-LC0011999/2021     	       N content too high	0.42
#
# USA/RI-CDC-LC0013352/2021     	       N content too high	0.33
#
# OU422018                      	       N content too high	0.39
#
# USA/NC-CDC-LC0015322/2021     	       N content too high	0.37
#
# OU392272                      	       N content too high	0.5
#
# OU392078                      	       N content too high	0.43
#
# USA/IN-CDC-LC0019420/2021     	       N content too high	0.43
#
# USA/CA-CDC-LC0024766/2021     	       N content too high	0.4
#
# USA/GA-CDC-LC0019799/2021     	       N content too high	0.36
#
# USA/VT-CDC-LC0020736/2021     	       N content too high	0.44
#
# USA/RI-CDC-LC0022695/2021     	       N content too high	0.36
#
# USA/NY-CDC-LC0023766/2021     	       N content too high	0.36
#
# USA/NC-CDC-LC0023676/2021     	       N content too high	0.43
#
# USA/CA-CDC-LC0026619/2021     	       N content too high	0.43
#
# USA/MO-CDC-LC0026893/2021     	       N content too high	0.33
#
# USA/NC-CDC-LC0025498/2021     	       N content too high	0.36
#
# USA/MD-CDC-LC0027884/2021     	       N content too high	0.41
#
# USA/CA-CDC-LC0026283/2021     	       N content too high	0.41
#
# USA/FL-CDC-LC0026468/2021     	       N content too high	0.4
#
# USA/NJ-CDC-LC0028061/2021     	       N content too high	0.33
#
# USA/NY-CDC-LC0029147/2021     	       N content too high	0.47
#
# USA/NJ-CDC-LC0027930/2021     	       N content too high	0.43
#
# USA/PA-CDC-LC0030964/2021     	       N content too high	0.33
#
# USA/NJ-CDC-LC0028676/2021     	       N content too high	0.38
#
# USA/NY-CDC-LC0031390/2021     	       N content too high	0.46
#
# OU347929                      	       N content too high	0.45
#
# Switzerland/TI-EOC-902_25886458/2021	       N content too high	0.45
#
# OU384646                      	       N content too high	0.4
#
# OU348522                      	       N content too high	0.45
#
# OU388858                      	       N content too high	0.45
#
# USA/UT-UPHL-210729493962/2021 	       N content too high	0.32
#
# OU488278                      	       N content too high	0.48
#
# OU488719                      	       N content too high	0.45
#
#
# Number of sequences detected: 10000
# Total passing QC: 9936
#
# Data files found:
# Trained model:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTree_v1.joblib
# Header file:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTreeHeaders_v1.joblib
# Designated hash:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/lineages.hash.csv
#
# Job stats:
# job                     count    min threads    max threads
# --------------------  -------  -------------  -------------
# add_failed_seqs             1              1              1
# align_to_reference          1              1              1
# all                         1              1              1
# generate_report             1              1              1
# get_constellations          1              1              1
# hash_sequence_assign        1              1              1
# pangolearn                  1              1              1
# scorpio                     1             32             32
# total                       8              1             32
#
# /home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # 3. Load up and join pangolin to metadata
#
# ## 3.1. Load pangolin results

# %%
import pandas as pd

pangolin_report = pangolin_out_dir / 'lineage_report.csv'

p_df = pd.read_csv(pangolin_report)
p_df
# Out:
#                               taxon     lineage  conflict  ambiguity_score  \
# 0                          LR882100    B.1.1.70       NaN              NaN
# 1                          LR882857   B.1.416.1       NaN              NaN
# 2                          LR882900    B.1.1.39       NaN              NaN
# 3                          LR884373         B.1       NaN              NaN
# 4                          LR898957  B.1.160.16       NaN              NaN
# ...                             ...         ...       ...              ...
# 9995                       OU348522        None       NaN              NaN
# 9996                       OU388858        None       NaN              NaN
# 9997  USA/UT-UPHL-210729493962/2021        None       NaN              NaN
# 9998                       OU488278        None       NaN              NaN
# 9999                       OU488719        None       NaN              NaN
#
#      scorpio_call  scorpio_support  scorpio_conflict        version  \
# 0             NaN              NaN               NaN  PANGO-v1.2.66
# 1             NaN              NaN               NaN  PANGO-v1.2.66
# 2             NaN              NaN               NaN  PANGO-v1.2.66
# 3             NaN              NaN               NaN  PANGO-v1.2.66
# 4             NaN              NaN               NaN  PANGO-v1.2.66
# ...           ...              ...               ...            ...
# 9995          NaN              NaN               NaN  PANGO-v1.2.66
# 9996          NaN              NaN               NaN  PANGO-v1.2.66
# 9997          NaN              NaN               NaN  PANGO-v1.2.66
# 9998          NaN              NaN               NaN  PANGO-v1.2.66
# 9999          NaN              NaN               NaN  PANGO-v1.2.66
#
#      pangolin_version pangoLEARN_version pango_version     status  \
# 0              3.1.11         2021-08-24       v1.2.66  passed_qc
# 1              3.1.11         2021-08-24       v1.2.66  passed_qc
# 2              3.1.11         2021-08-24       v1.2.66  passed_qc
# 3              3.1.11         2021-08-24       v1.2.66  passed_qc
# 4              3.1.11         2021-08-24       v1.2.66  passed_qc
# ...               ...                ...           ...        ...
# 9995           3.1.11         2021-08-24       v1.2.66       fail
# 9996           3.1.11         2021-08-24       v1.2.66       fail
# 9997           3.1.11         2021-08-24       v1.2.66       fail
# 9998           3.1.11         2021-08-24       v1.2.66       fail
# 9999           3.1.11         2021-08-24       v1.2.66       fail
#
#                                  note
# 0     Assigned from designation hash.
# 1     Assigned from designation hash.
# 2     Assigned from designation hash.
# 3     Assigned from designation hash.
# 4     Assigned from designation hash.
# ...                               ...
# 9995                   N_content:0.45
# 9996                   N_content:0.45
# 9997                   N_content:0.32
# 9998                   N_content:0.48
# 9999                   N_content:0.45
#
# [10000 rows x 13 columns]

# %% [markdown]
# ## 3.2. Load other metadata

# %%
import pandas as pd

metadata_df = pd.read_csv(subset_metadata_path, sep='\t')
metadata_df
# Out:
#                            strain virus   gisaid_epi_isl genbank_accession  \
# 0        England/QEUH-9F48A4/2020  ncov   EPI_ISL_588307          OA992707
# 1     USA/UT-CDC-QDX26118077/2021  ncov  EPI_ISL_2873924          MZ534972
# 2       USA/IA-CDC-2-4503024/2021  ncov  EPI_ISL_2709554          MZ453424
# 3                        OU163868  ncov                ?          OU163868
# 4        England/QEUH-A5E063/2020  ncov   EPI_ISL_597431          OA995643
# ...                           ...   ...              ...               ...
# 9995  USA/NJ-CDC-QDX24758678/2021  ncov  EPI_ISL_2369287          MZ319327
# 9996     USA/VT-MASPHL-02207/2021  ncov                ?          MW893851
# 9997    England/ALDP-16967D4/2021  ncov  EPI_ISL_2605675          OU337161
# 9998        USA/TX-DSHS-2441/2020  ncov                ?          MW724764
# 9999     England/CAMC-B99A21/2020  ncov   EPI_ISL_673341          OD898730
#
#      sra_accession        date         region         country  \
# 0       ERR4688590  2020-09-25         Europe  United Kingdom
# 1              NaN  2021-06-22  North America             USA
# 2              NaN  2021-05-25  North America             USA
# 3              NaN  2021-05-04         Europe         Germany
# 4       ERR4763980  2020-10-12         Europe  United Kingdom
# ...            ...         ...            ...             ...
# 9995           NaN  2021-05-07  North America             USA
# 9996           NaN  2021-02-10  North America             USA
# 9997    ERR6105992  2021-06-08         Europe  United Kingdom
# 9998   SRR13660100  2020-06-24  North America             USA
# 9999    ERR4909291  2020-11-15         Europe  United Kingdom
#
#              division location  ... missing_data divergence nonACGTN  \
# 0             England      NaN  ...        121.0       15.0      1.0
# 1                Utah      NaN  ...          0.0       37.0      0.0
# 2                Iowa      NaN  ...          1.0       37.0      0.0
# 3     Rheinland-Pfalz      NaN  ...          0.0       38.0      0.0
# 4             England      NaN  ...        121.0       16.0      0.0
# ...               ...      ...  ...          ...        ...      ...
# 9995       New Jersey      NaN  ...          0.0       41.0      0.0
# 9996              USA      NaN  ...        220.0       21.0      0.0
# 9997          England      NaN  ...        121.0       40.0      0.0
# 9998            Texas      NaN  ...       3695.0       11.0      0.0
# 9999          England      NaN  ...        121.0       16.0      0.0
#
#      rare_mutations  snp_clusters QC_missing_data QC_mixed_sites  \
# 0               1.0           0.0            good           good
# 1               5.0           0.0            good           good
# 2              11.0           0.0            good           good
# 3               9.0           0.0            good           good
# 4               1.0           0.0            good           good
# ...             ...           ...             ...            ...
# 9995           14.0           0.0            good           good
# 9996            8.0           0.0            good           good
# 9997           16.0           0.0            good           good
# 9998            0.0           0.0             bad           good
# 9999            5.0           0.0            good           good
#
#      QC_rare_mutations QC_snp_clusters clock_deviation
# 0                 good            good             0.0
# 1                 good            good             1.0
# 2                 good            good            -1.0
# 3                 good            good             0.0
# 4                 good            good             0.0
# ...                ...             ...             ...
# 9995              good            good             3.0
# 9996              good            good            -2.0
# 9997          mediocre            good             0.0
# 9998              good            good             0.0
# 9999              good            good            -1.0
#
# [10000 rows x 39 columns]

# %%
metadata_df.columns
# Out:
# Index(['strain', 'virus', 'gisaid_epi_isl', 'genbank_accession',
#        'sra_accession', 'date', 'region', 'country', 'division', 'location',
#        'region_exposure', 'country_exposure', 'division_exposure', 'segment',
#        'length', 'host', 'age', 'sex', 'Nextstrain_clade', 'pango_lineage',
#        'GISAID_clade', 'originating_lab', 'submitting_lab', 'authors', 'url',
#        'title', 'paper_url', 'date_submitted', 'sampling_strategy',
#        'missing_data', 'divergence', 'nonACGTN', 'rare_mutations',
#        'snp_clusters', 'QC_missing_data', 'QC_mixed_sites',
#        'QC_rare_mutations', 'QC_snp_clusters', 'clock_deviation'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Join to pangolin results

# %%
metadata_pangolin_df = metadata_df.merge(p_df, left_on='strain', right_on='taxon')
metadata_pangolin_df
# Out:
#                            strain virus   gisaid_epi_isl genbank_accession  \
# 0        England/QEUH-9F48A4/2020  ncov   EPI_ISL_588307          OA992707
# 1     USA/UT-CDC-QDX26118077/2021  ncov  EPI_ISL_2873924          MZ534972
# 2       USA/IA-CDC-2-4503024/2021  ncov  EPI_ISL_2709554          MZ453424
# 3                        OU163868  ncov                ?          OU163868
# 4        England/QEUH-A5E063/2020  ncov   EPI_ISL_597431          OA995643
# ...                           ...   ...              ...               ...
# 9995  USA/NJ-CDC-QDX24758678/2021  ncov  EPI_ISL_2369287          MZ319327
# 9996     USA/VT-MASPHL-02207/2021  ncov                ?          MW893851
# 9997    England/ALDP-16967D4/2021  ncov  EPI_ISL_2605675          OU337161
# 9998        USA/TX-DSHS-2441/2020  ncov                ?          MW724764
# 9999     England/CAMC-B99A21/2020  ncov   EPI_ISL_673341          OD898730
#
#      sra_accession        date         region         country  \
# 0       ERR4688590  2020-09-25         Europe  United Kingdom
# 1              NaN  2021-06-22  North America             USA
# 2              NaN  2021-05-25  North America             USA
# 3              NaN  2021-05-04         Europe         Germany
# 4       ERR4763980  2020-10-12         Europe  United Kingdom
# ...            ...         ...            ...             ...
# 9995           NaN  2021-05-07  North America             USA
# 9996           NaN  2021-02-10  North America             USA
# 9997    ERR6105992  2021-06-08         Europe  United Kingdom
# 9998   SRR13660100  2020-06-24  North America             USA
# 9999    ERR4909291  2020-11-15         Europe  United Kingdom
#
#              division location  ... ambiguity_score            scorpio_call  \
# 0             England      NaN  ...             NaN                     NaN
# 1                Utah      NaN  ...        1.000000  Delta (B.1.617.2-like)
# 2                Iowa      NaN  ...        1.000000    Alpha (B.1.1.7-like)
# 3     Rheinland-Pfalz      NaN  ...        1.000000    Alpha (B.1.1.7-like)
# 4             England      NaN  ...             NaN                     NaN
# ...               ...      ...  ...             ...                     ...
# 9995       New Jersey      NaN  ...        1.000000    Alpha (B.1.1.7-like)
# 9996              USA      NaN  ...        0.991766                     NaN
# 9997          England      NaN  ...        1.000000    Alpha (B.1.1.7-like)
# 9998            Texas      NaN  ...        0.845244                     NaN
# 9999          England      NaN  ...             NaN                     NaN
#
#      scorpio_support scorpio_conflict         version pangolin_version  \
# 0                NaN              NaN   PANGO-v1.2.66           3.1.11
# 1             1.0000           0.0000  PLEARN-v1.2.66           3.1.11
# 2             0.9565           0.0435  PLEARN-v1.2.66           3.1.11
# 3             0.9130           0.0435  PLEARN-v1.2.66           3.1.11
# 4                NaN              NaN   PANGO-v1.2.66           3.1.11
# ...              ...              ...             ...              ...
# 9995          0.9565           0.0435  PLEARN-v1.2.66           3.1.11
# 9996             NaN              NaN  PLEARN-v1.2.66           3.1.11
# 9997          0.9565           0.0435  PLEARN-v1.2.66           3.1.11
# 9998             NaN              NaN  PLEARN-v1.2.66           3.1.11
# 9999             NaN              NaN   PANGO-v1.2.66           3.1.11
#
#      pangoLEARN_version pango_version     status  \
# 0            2021-08-24       v1.2.66  passed_qc
# 1            2021-08-24       v1.2.66  passed_qc
# 2            2021-08-24       v1.2.66  passed_qc
# 3            2021-08-24       v1.2.66  passed_qc
# 4            2021-08-24       v1.2.66  passed_qc
# ...                 ...           ...        ...
# 9995         2021-08-24       v1.2.66  passed_qc
# 9996         2021-08-24       v1.2.66  passed_qc
# 9997         2021-08-24       v1.2.66  passed_qc
# 9998         2021-08-24       v1.2.66  passed_qc
# 9999         2021-08-24       v1.2.66  passed_qc
#
#                                                    note
# 0                       Assigned from designation hash.
# 1     scorpio call: Alt alleles 13; Ref alleles 0; A...
# 2     scorpio call: Alt alleles 22; Ref alleles 1; A...
# 3     scorpio call: Alt alleles 21; Ref alleles 1; A...
# 4                       Assigned from designation hash.
# ...                                                 ...
# 9995  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9996                                                NaN
# 9997  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 9998                                                NaN
# 9999                    Assigned from designation hash.
#
# [10000 rows x 52 columns]

# %% [markdown]
# # 4. Save joined metadata to file

# %%
metadata_pangolin_df.to_csv(output_metadata_pangolin_path, sep='\t', index=False)

print(f'Saved metadata and pangolin to {output_metadata_pangolin_path}')
# Out:
# Saved metadata and pangolin to input/metadata-subsample-pangolin.tsv
