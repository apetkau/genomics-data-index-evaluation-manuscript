# %% [markdown]
# # 1. Parameters

# %%
sequences_split_dir = 'input/split'
sequences_subset_all = 'input/all.fasta.gz'
pangolin_out_dir = 'input/pangolin'
subset_metadata_path = 'input/metadata-subsample.tsv'
output_metadata_pangolin_path = 'input/metadata-subsample-pangolin.tsv'

# %%
from pathlib import Path

sequences_split_dir = Path(sequences_split_dir)
sequences_subset_all = Path(sequences_subset_all)
pangolin_out_dir = Path(pangolin_out_dir)
subset_metadata_path = Path(subset_metadata_path)
output_metadata_pangolin_path = Path(output_metadata_pangolin_path)

# %% [markdown]
# # 2. Run pangolin

# %%
# !conda run --name pangolin pangolin --all-versions
# Out:
# pangolin: 3.1.20
# pangolearn: 2022-02-28
# constellations: v0.1.3
# scorpio: 0.3.16
# pango-designation used by pangoLEARN/Usher: v1.2.127
# pango-designation aliases: 1.2.132

# %%
# !conda run --name pangolin pangolin -t 52 -o {pangolin_out_dir} {sequences_subset_all}
# Out:
# loading model 03/10/2022, 11:05:34
# processing block of 1000 sequences 03/10/2022, 11:05:42
# processing block of 1000 sequences 03/10/2022, 11:05:47
# processing block of 1000 sequences 03/10/2022, 11:05:52
# processing block of 1000 sequences 03/10/2022, 11:05:56
# processing block of 1000 sequences 03/10/2022, 11:06:01
# processing block of 1000 sequences 03/10/2022, 11:06:06
# processing block of 1000 sequences 03/10/2022, 11:06:11
# processing block of 1000 sequences 03/10/2022, 11:06:15
# processing block of 1000 sequences 03/10/2022, 11:06:20
# processing block of 1000 sequences 03/10/2022, 11:06:25
# processing block of 1000 sequences 03/10/2022, 11:06:30
# processing block of 1000 sequences 03/10/2022, 11:06:34
# processing block of 1000 sequences 03/10/2022, 11:06:39
# processing block of 1000 sequences 03/10/2022, 11:06:44
# processing block of 1000 sequences 03/10/2022, 11:06:48
# processing block of 1000 sequences 03/10/2022, 11:06:53
# processing block of 1000 sequences 03/10/2022, 11:06:58
# processing block of 1000 sequences 03/10/2022, 11:07:03
# processing block of 1000 sequences 03/10/2022, 11:07:07
# processing block of 1000 sequences 03/10/2022, 11:07:12
# processing block of 1000 sequences 03/10/2022, 11:07:17
# processing block of 1000 sequences 03/10/2022, 11:07:21
# processing block of 1000 sequences 03/10/2022, 11:07:26
# processing block of 1000 sequences 03/10/2022, 11:07:31
# processing block of 1000 sequences 03/10/2022, 11:07:36
# processing block of 1000 sequences 03/10/2022, 11:07:40
# processing block of 1000 sequences 03/10/2022, 11:07:45
# processing block of 1000 sequences 03/10/2022, 11:07:50
# processing block of 1000 sequences 03/10/2022, 11:07:55
# processing block of 1000 sequences 03/10/2022, 11:07:59
# processing block of 1000 sequences 03/10/2022, 11:08:04
# processing block of 1000 sequences 03/10/2022, 11:08:09
# processing block of 1000 sequences 03/10/2022, 11:08:14
# processing block of 1000 sequences 03/10/2022, 11:08:18
# processing block of 1000 sequences 03/10/2022, 11:08:23
# processing block of 1000 sequences 03/10/2022, 11:08:28
# processing block of 1000 sequences 03/10/2022, 11:08:33
# processing block of 1000 sequences 03/10/2022, 11:08:38
# processing block of 1000 sequences 03/10/2022, 11:08:42
# processing block of 1000 sequences 03/10/2022, 11:08:47
# processing block of 1000 sequences 03/10/2022, 11:08:52
# processing block of 1000 sequences 03/10/2022, 11:08:57
# processing block of 1000 sequences 03/10/2022, 11:09:02
# processing block of 1000 sequences 03/10/2022, 11:09:07
# processing block of 1000 sequences 03/10/2022, 11:09:12
# processing block of 1000 sequences 03/10/2022, 11:09:17
# processing block of 1000 sequences 03/10/2022, 11:09:21
# processing block of 1000 sequences 03/10/2022, 11:09:26
# processing block of 1000 sequences 03/10/2022, 11:09:31
# processing block of 1000 sequences 03/10/2022, 11:09:36
# processing block of 1000 sequences 03/10/2022, 11:09:40
# processing block of 1000 sequences 03/10/2022, 11:09:45
# processing block of 1000 sequences 03/10/2022, 11:09:50
# processing block of 1000 sequences 03/10/2022, 11:09:55
# processing block of 1000 sequences 03/10/2022, 11:09:59
# processing block of 1000 sequences 03/10/2022, 11:10:04
# processing block of 1000 sequences 03/10/2022, 11:10:09
# processing block of 1000 sequences 03/10/2022, 11:10:13
# processing block of 1000 sequences 03/10/2022, 11:10:18
# processing block of 1000 sequences 03/10/2022, 11:10:23
# processing block of 1000 sequences 03/10/2022, 11:10:28
# processing block of 1000 sequences 03/10/2022, 11:10:32
# processing block of 1000 sequences 03/10/2022, 11:10:37
# processing block of 1000 sequences 03/10/2022, 11:10:42
# processing block of 1000 sequences 03/10/2022, 11:10:46
# processing block of 1000 sequences 03/10/2022, 11:10:51
# processing block of 1000 sequences 03/10/2022, 11:10:56
# processing block of 1000 sequences 03/10/2022, 11:11:01
# processing block of 1000 sequences 03/10/2022, 11:11:05
# processing block of 441 sequences 03/10/2022, 11:11:09
# complete 03/10/2022, 11:11:10
# Output file written to: /home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/pangolin/lineage_report.csv
# All dependencies satisfied.
# The query file is:/home/CSCScience.ca/apetkau/workspace/genomics-data-index-evaluation/evaluations/sars-cov-2/input/all.fasta.gz
# ** Running sequence QC **
# Number of sequences detected: 100000
# Total passing QC: 99492
#
# Data files found:
# Trained model:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTree_v1.joblib
# Header file:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/decisionTreeHeaders_v1.joblib
# Designated hash:	/home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/pangoLEARN/data/lineages.hash.csv
#
# Job stats:
# job                     count    min threads    max threads
# --------------------  -------  -------------  -------------
# add_failed_seqs             1              1              1
# align_to_reference          1              1              1
# all                         1              1              1
# generate_report             1              1              1
# get_constellations          1              1              1
# hash_sequence_assign        1              1              1
# pangolearn                  1              1              1
# scorpio                     1             52             52
# total                       8              1             52
#
# /home/CSCScience.ca/apetkau/miniconda3/envs/pangolin/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # 3. Load up and join pangolin to metadata
#
# ## 3.1. Load pangolin results

# %%
import pandas as pd

pangolin_report = pangolin_out_dir / 'lineage_report.csv'

p_df = pd.read_csv(pangolin_report)
p_df
# Out:
#                                            taxon lineage  conflict  \
# 0                       Wuhan/IPBCAMS-WH-04/2019       B       NaN
# 1                        CHN/Wuhan_IME-WH05/2019       B       NaN
# 2                        Switzerland/100108/2020     B.1       NaN
# 3                        Switzerland/100816/2020     B.1       NaN
# 4                                       LR862442    C.35       NaN
# ...                                          ...     ...       ...
# 99995                                   OU488207    None       NaN
# 99996                                   OU490562    None       NaN
# 99997                                   OU490569    None       NaN
# 99998                                   OU490836    None       NaN
# 99999  USA/D4F17D14A7C44B168CD47F1B0D34ADB7/2021    None       NaN
#
#        ambiguity_score scorpio_call  scorpio_support  scorpio_conflict  \
# 0                  NaN          NaN              NaN               NaN
# 1                  NaN          NaN              NaN               NaN
# 2                  NaN          NaN              NaN               NaN
# 3                  NaN          NaN              NaN               NaN
# 4                  NaN          NaN              NaN               NaN
# ...                ...          ...              ...               ...
# 99995              NaN          NaN              NaN               NaN
# 99996              NaN          NaN              NaN               NaN
# 99997              NaN          NaN              NaN               NaN
# 99998              NaN          NaN              NaN               NaN
# 99999              NaN          NaN              NaN               NaN
#
#               version pangolin_version pangoLEARN_version pango_version  \
# 0      PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 1      PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 2      PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 3      PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 4      PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# ...               ...              ...                ...           ...
# 99995  PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 99996  PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 99997  PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 99998  PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
# 99999  PANGO-v1.2.127           3.1.20         2022-02-28      v1.2.127
#
#           status                             note
# 0      passed_qc  Assigned from designation hash.
# 1      passed_qc  Assigned from designation hash.
# 2      passed_qc  Assigned from designation hash.
# 3      passed_qc  Assigned from designation hash.
# 4      passed_qc  Assigned from designation hash.
# ...          ...                              ...
# 99995       fail                   N_content:0.41
# 99996       fail                   N_content:0.47
# 99997       fail                   N_content:0.45
# 99998       fail                   N_content:0.31
# 99999       fail                   N_content:0.32
#
# [100000 rows x 13 columns]

# %% [markdown]
# ## 3.2. Load other metadata

# %%
import pandas as pd

metadata_df = pd.read_csv(subset_metadata_path, sep='\t')
metadata_df
# Out:
#                                  strain virus   gisaid_epi_isl  \
# 0                              OU420663  ncov                ?
# 1             USA/NY-CUIMC-NP-3606/2020  ncov                ?
# 2      Switzerland/BL-UHB-42491849/2020  ncov   EPI_ISL_930932
# 3            Scotland/QEUH-1618558/2021  ncov  EPI_ISL_2487678
# 4            Scotland/QEUH-16829C6/2021  ncov  EPI_ISL_2554507
# ...                                 ...   ...              ...
# 99995       USA/OH-CDC-QDX23654955/2021  ncov  EPI_ISL_1669162
# 99996         USA/KS-CDC-LC0014845/2021  ncov  EPI_ISL_1255089
# 99997                 USA/WA-S5065/2020  ncov  EPI_ISL_1114222
# 99998         England/MILK-10AE881/2021  ncov   EPI_ISL_993691
# 99999          England/ALDP-B5B038/2020  ncov   EPI_ISL_655604
#
#       genbank_accession sra_accession        date         region  \
# 0              OU420663    ERR5939958        2020         Europe
# 1              MZ702266           NaN  2020-12-02  North America
# 2              OU281100           NaN  2020-10-18         Europe
# 3              OU314699    ERR6069165  2021-06-02         Europe
# 4              OU329920    ERR6085250  2021-06-10         Europe
# ...                 ...           ...         ...            ...
# 99995          MW989219           NaN  2021-04-05  North America
# 99996          MW704675           NaN  2021-02-09  North America
# 99997          MW689132           NaN  2020-11-06  North America
# 99998          OD978562    ERR5303908  2021-01-17         Europe
# 99999          OB997017    ERR4877748  2020-11-08         Europe
#
#               country    division             location  ... divergence  \
# 0      United Kingdom     England                  NaN  ...       40.0
# 1                 USA    New York        New York City  ...       21.0
# 2         Switzerland  Basel-Land                  NaN  ...       19.0
# 3      United Kingdom    Scotland                  NaN  ...       33.0
# 4      United Kingdom    Scotland                  NaN  ...       37.0
# ...               ...         ...                  ...  ...        ...
# 99995             USA        Ohio                  NaN  ...       35.0
# 99996             USA      Kansas                  NaN  ...       21.0
# 99997             USA  Washington  Grays Harbor County  ...       14.0
# 99998  United Kingdom     England                  NaN  ...       32.0
# 99999  United Kingdom     England                  NaN  ...       16.0
#
#       nonACGTN rare_mutations snp_clusters  QC_missing_data QC_mixed_sites  \
# 0          0.0           15.0          0.0             good           good
# 1          0.0            7.0          0.0         mediocre           good
# 2          0.0            6.0          0.0             good           good
# 3          0.0            7.0          0.0         mediocre           good
# 4          0.0            5.0          0.0             good           good
# ...        ...            ...          ...              ...            ...
# 99995      0.0            9.0          0.0             good           good
# 99996      0.0            6.0          0.0             good           good
# 99997      0.0            0.0          0.0             good           good
# 99998      0.0            7.0          0.0             good           good
# 99999      0.0            3.0          0.0             good           good
#
#       QC_rare_mutations QC_snp_clusters clock_deviation missing_data_percent
# 0                  good            good               ?             0.351135
# 1                  good            good             0.0             4.417617
# 2                  good            good             0.0             0.297629
# 3                  good            good            -5.0             3.885898
# 4                  good            good             1.0             0.404642
# ...                 ...             ...             ...                  ...
# 99995              good            good             0.0             0.000000
# 99996              good            good            -2.0             3.394308
# 99997              good            good            -2.0             0.006688
# 99998              good            good             0.0             1.595158
# 99999              good            good            -1.0             2.324182
#
# [100000 rows x 40 columns]

# %%
metadata_df.columns
# Out:
# Index(['strain', 'virus', 'gisaid_epi_isl', 'genbank_accession',
#        'sra_accession', 'date', 'region', 'country', 'division', 'location',
#        'region_exposure', 'country_exposure', 'division_exposure', 'segment',
#        'length', 'host', 'age', 'sex', 'Nextstrain_clade', 'pango_lineage',
#        'GISAID_clade', 'originating_lab', 'submitting_lab', 'authors', 'url',
#        'title', 'paper_url', 'date_submitted', 'sampling_strategy',
#        'missing_data', 'divergence', 'nonACGTN', 'rare_mutations',
#        'snp_clusters', 'QC_missing_data', 'QC_mixed_sites',
#        'QC_rare_mutations', 'QC_snp_clusters', 'clock_deviation',
#        'missing_data_percent'],
#       dtype='object')

# %% [markdown]
# ## 3.3. Join to pangolin results

# %%
metadata_pangolin_df = metadata_df.merge(p_df, left_on='strain', right_on='taxon')
metadata_pangolin_df
# Out:
#                                  strain virus   gisaid_epi_isl  \
# 0                              OU420663  ncov                ?
# 1             USA/NY-CUIMC-NP-3606/2020  ncov                ?
# 2      Switzerland/BL-UHB-42491849/2020  ncov   EPI_ISL_930932
# 3            Scotland/QEUH-1618558/2021  ncov  EPI_ISL_2487678
# 4            Scotland/QEUH-16829C6/2021  ncov  EPI_ISL_2554507
# ...                                 ...   ...              ...
# 99995       USA/OH-CDC-QDX23654955/2021  ncov  EPI_ISL_1669162
# 99996         USA/KS-CDC-LC0014845/2021  ncov  EPI_ISL_1255089
# 99997                 USA/WA-S5065/2020  ncov  EPI_ISL_1114222
# 99998         England/MILK-10AE881/2021  ncov   EPI_ISL_993691
# 99999          England/ALDP-B5B038/2020  ncov   EPI_ISL_655604
#
#       genbank_accession sra_accession        date         region  \
# 0              OU420663    ERR5939958        2020         Europe
# 1              MZ702266           NaN  2020-12-02  North America
# 2              OU281100           NaN  2020-10-18         Europe
# 3              OU314699    ERR6069165  2021-06-02         Europe
# 4              OU329920    ERR6085250  2021-06-10         Europe
# ...                 ...           ...         ...            ...
# 99995          MW989219           NaN  2021-04-05  North America
# 99996          MW704675           NaN  2021-02-09  North America
# 99997          MW689132           NaN  2020-11-06  North America
# 99998          OD978562    ERR5303908  2021-01-17         Europe
# 99999          OB997017    ERR4877748  2020-11-08         Europe
#
#               country    division             location  ... ambiguity_score  \
# 0      United Kingdom     England                  NaN  ...        1.000000
# 1                 USA    New York        New York City  ...        0.951273
# 2         Switzerland  Basel-Land                  NaN  ...             NaN
# 3      United Kingdom    Scotland                  NaN  ...        0.970092
# 4      United Kingdom    Scotland                  NaN  ...             NaN
# ...               ...         ...                  ...  ...             ...
# 99995             USA        Ohio                  NaN  ...        1.000000
# 99996             USA      Kansas                  NaN  ...        0.976650
# 99997             USA  Washington  Grays Harbor County  ...        1.000000
# 99998  United Kingdom     England                  NaN  ...             NaN
# 99999  United Kingdom     England                  NaN  ...             NaN
#
#                scorpio_call scorpio_support scorpio_conflict          version  \
# 0      Alpha (B.1.1.7-like)          1.0000           0.0000  PLEARN-v1.2.127
# 1                       NaN             NaN              NaN  PLEARN-v1.2.127
# 2                       NaN             NaN              NaN   PANGO-v1.2.127
# 3      Alpha (B.1.1.7-like)          0.8696           0.0435  PLEARN-v1.2.127
# 4         Delta (AY.4-like)          0.9688           0.0000   PANGO-v1.2.127
# ...                     ...             ...              ...              ...
# 99995  Alpha (B.1.1.7-like)          0.9565           0.0435  PLEARN-v1.2.127
# 99996                   NaN             NaN              NaN  PLEARN-v1.2.127
# 99997                   NaN             NaN              NaN  PLEARN-v1.2.127
# 99998  Alpha (B.1.1.7-like)          0.9565           0.0435   PANGO-v1.2.127
# 99999                   NaN             NaN              NaN   PANGO-v1.2.127
#
#       pangolin_version pangoLEARN_version pango_version     status  \
# 0               3.1.20         2022-02-28      v1.2.127  passed_qc
# 1               3.1.20         2022-02-28      v1.2.127  passed_qc
# 2               3.1.20         2022-02-28      v1.2.127  passed_qc
# 3               3.1.20         2022-02-28      v1.2.127  passed_qc
# 4               3.1.20         2022-02-28      v1.2.127  passed_qc
# ...                ...                ...           ...        ...
# 99995           3.1.20         2022-02-28      v1.2.127  passed_qc
# 99996           3.1.20         2022-02-28      v1.2.127  passed_qc
# 99997           3.1.20         2022-02-28      v1.2.127  passed_qc
# 99998           3.1.20         2022-02-28      v1.2.127  passed_qc
# 99999           3.1.20         2022-02-28      v1.2.127  passed_qc
#
#                                                     note
# 0      scorpio call: Alt alleles 23; Ref alleles 0; A...
# 1                                                    NaN
# 2                        Assigned from designation hash.
# 3      scorpio call: Alt alleles 20; Ref alleles 1; A...
# 4      scorpio call: Alt alleles 31; Ref alleles 0; A...
# ...                                                  ...
# 99995  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 99996                                                NaN
# 99997                                                NaN
# 99998  scorpio call: Alt alleles 22; Ref alleles 1; A...
# 99999                    Assigned from designation hash.
#
# [100000 rows x 53 columns]

# %% [markdown]
# # 4. Save joined metadata to file

# %%
metadata_pangolin_df.to_csv(output_metadata_pangolin_path, sep='\t', index=False)

print(f'Saved metadata and pangolin to {output_metadata_pangolin_path}')
# Out:
# Saved metadata and pangolin to input/metadata-subsample-pangolin.tsv
